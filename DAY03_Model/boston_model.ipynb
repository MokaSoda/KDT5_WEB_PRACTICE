# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import torch.utils.data as Data
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# #### [Pytorch 기반 회귀 모델 구현]
# - Layer => Full Connected Layer
# - Loss Function => MSELoss, MAELoss
# - Optimizer => Adam
# - Model => Linear Regression
# - Dataset => BostonHousing
# - DataLoader => DataLoader
# - Data => TensorDataset
# - Model => Linear Regression
# - Loss Function => MSE
# - Optimizer => Adam
# - Train => 1000
# - Test => 100
# - Epoch => 100
# - Batch Size => 10
# - 결과 => 0.11

# %%
dfboston = pd.read_csv('./data/BostonHousing.csv')
dfboston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
class CustomData(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = pd.read_csv(csv_file)
        self.transform = transform
        self.x = torch.tensor(self.data.iloc[:, :-1].values, dtype=torch.float32, device=DEVICE)
        self.y = torch.tensor(self.data.iloc[:, -1].values, dtype=torch.float32, device=DEVICE)
        
    def __len__(self):
        return self.data.shape[0]
    
    def __getitem__(self, idx):
            
        x = self.x[idx]
        y = self.y[idx]
            
        return x, y
    
    def normalization(self):
        result = self.x.max(dim=1)
        return result
        
        
    
dataset = CustomData('./data/BostonHousing.csv')
# dataset.normalization()

# %%
train, test = random_split(dataset, [0.8, 0.2])

train.indices.__len__(), test.indices.__len__()
# Out:
# (405, 101)

# %%
trainloader = DataLoader(train, batch_size=50, shuffle=True, drop_last=True)
testloader = DataLoader(test, batch_size=50, shuffle=False, drop_last=True)

# %%
class LinearRegression(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(13, 131)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(131, 1)
    
    def forward(self, x):
        x = self.linear(x)
        x = self.relu(x)
        x = self.linear2(x)
        return x
    

model = LinearRegression().to(DEVICE)
criterion = nn.MSELoss().to(DEVICE)
optimizer = optim.Adam(model.parameters(), lr=0.0001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', patience=10)

# %%
from torchmetrics.regression import MeanSquaredError, MeanAbsoluteError, R2Score

def train(model, trainloader, criterion, optimizer):
    model.train()
    lossResult = []
    r2 = R2Score().to(DEVICE)
    mae = MeanAbsoluteError().to(DEVICE)
    mse = MeanSquaredError().to(DEVICE)
    for inputs, labels in trainloader:
        
        outputs = model(inputs)
        labels = labels.reshape(-1, 1)
        loss = criterion(outputs, labels)
        r2(outputs, labels)
        mae(outputs, labels)
        mse(outputs, labels)
        
        lossResult.append(loss.item())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    lossavg = np.mean(lossResult)
    r2avg = r2.compute().cpu().item()
    print(f'Train Loss : {lossavg:.4f}', end='  ')
    print(f'Train R2 : {r2avg:.4f}')
    
    return lossavg, r2avg

def test(model, testloader, loss):
    model.eval()
    lossResult = []
    r2 = R2Score().to(DEVICE)
    mae = MeanAbsoluteError().to(DEVICE)
    mse = MeanSquaredError().to(DEVICE)
    
    with torch.no_grad():
        for inputs, labels in testloader:
            outputs = model(inputs)
            labels = labels.reshape(-1, 1)
            r2(outputs, labels)
            mae(outputs, labels)
            mse(outputs, labels)
            
            lossresult = loss(outputs, labels)
            lossResult.append(lossresult.item())
            
    lossavg = np.mean(lossResult)
    r2avg = r2.compute().cpu().item()
    maeavg = mae.compute().cpu().item()
    mseavg = mse.compute().cpu().item()

    print(f'Test Loss : {lossavg:.4f}', end='  ' )
    print(f"Test R2 : {r2avg:.4f}")
    # print(f"Test MAE : {maeavg:.4f}")
    # print(f"Test MSE : {mseavg:.4f}")
    
    
    return lossavg, r2avg, maeavg, mseavg

# %%
from tqdm import tqdm
EPOCHES = 10000

for epoch in range(EPOCHES):
    print(f'Epoch : {epoch+1}')
    lossavg, r2avg = train(model, trainloader, criterion, optimizer)
    test(model, testloader, criterion)
    # stop using patience criteria
    
    # scheduler.step(lossavg)
    # if scheduler.num_bad_epochs > scheduler.patience:
    #     print(f'Early stopping at epoch {epoch}...')
    #     break
# Out:
# Epoch : 1
# Train Loss : 610.2045  Train R2 : -6.1022
# Test Loss : 641.8383  Test R2 : -6.9414
# Epoch : 2
# Train Loss : 525.2482  Train R2 : -5.2745
# Test Loss : 561.4122  Test R2 : -5.9463
# Epoch : 3
# Train Loss : 457.7741  Train R2 : -4.3894
# Test Loss : 488.7327  Test R2 : -5.0470
# Epoch : 4
# Train Loss : 399.6127  Train R2 : -3.6718
# Test Loss : 425.4091  Test R2 : -4.2635
# Epoch : 5
# Train Loss : 347.5386  Train R2 : -3.1667
# Test Loss : 370.1681  Test R2 : -3.5800
# Epoch : 6
# Train Loss : 310.0963  Train R2 : -2.6254
# Test Loss : 321.7778  Test R2 : -2.9813
# Epoch : 7
# Train Loss : 267.7544  Train R2 : -2.1458
# Test Loss : 277.8856  Test R2 : -2.4382
# Epoch : 8
# Train Loss : 235.8546  Train R2 : -1.7452
# Test Loss : 241.5800  Test R2 : -1.9890
# Epoch : 9
# Train Loss : 207.5810  Train R2 : -1.4309
# Test Loss : 210.8917  Test R2 : -1.6093
# Epoch : 10
# Train Loss : 181.0621  Train R2 : -1.1558
# Test Loss : 184.9581  Test R2 : -1.2885
# Epoch : 11
# Train Loss : 164.4144  Train R2 : -0.9120
# Test Loss : 162.8884  Test R2 : -1.0154
# Epoch : 12
# Train Loss : 145.7035  Train R2 : -0.7111
# Test Loss : 144.4522  Test R2 : -0.7873
# Epoch : 13
# Train Loss : 134.0556  Train R2 : -0.5598
# Test Loss : 129.0771  Test R2 : -0.5971
# Epoch : 14
# Train Loss : 121.4405  Train R2 : -0.4242
# Test Loss : 116.9355  Test R2 : -0.4468
# Epoch : 15
# Train Loss : 112.4256  Train R2 : -0.3084
# Test Loss : 106.8251  Test R2 : -0.3217
# Epoch : 16
# Train Loss : 103.1546  Train R2 : -0.2321
# Test Loss : 98.5402  Test R2 : -0.2192
# Epoch : 17
# Train Loss : 98.8191  Train R2 : -0.1554
# Test Loss : 92.0516  Test R2 : -0.1389
# Epoch : 18
# Train Loss : 94.3635  Train R2 : -0.0987
# Test Loss : 86.6996  Test R2 : -0.0727
# Epoch : 19
# Train Loss : 90.5550  Train R2 : -0.0567
# Test Loss : 82.4621  Test R2 : -0.0203
# Epoch : 20
# Train Loss : 86.9302  Train R2 : -0.0246
# Test Loss : 78.7363  Test R2 : 0.0258
# Epoch : 21
# Train Loss : 84.6915  Train R2 : 0.0122
# Test Loss : 75.9661  Test R2 : 0.0601
# Epoch : 22
# Train Loss : 80.9133  Train R2 : 0.0390
# Test Loss : 73.6184  Test R2 : 0.0891
# Epoch : 23
# Train Loss : 81.6388  Train R2 : 0.0485
# Test Loss : 71.7839  Test R2 : 0.1118
# Epoch : 24
# Train Loss : 78.9192  Train R2 : 0.0590
# Test Loss : 70.1207  Test R2 : 0.1324
# Epoch : 25
# Train Loss : 77.7883  Train R2 : 0.0845
# Test Loss : 69.1938  Test R2 : 0.1439
# Epoch : 26
# Train Loss : 75.9231  Train R2 : 0.0969
# Test Loss : 67.9905  Test R2 : 0.1588
# Epoch : 27
# Train Loss : 76.8922  Train R2 : 0.1007
# Test Loss : 66.6080  Test R2 : 0.1759
# Epoch : 28
# Train Loss : 76.1438  Train R2 : 0.1124
# Test Loss : 65.7033  Test R2 : 0.1871
# Epoch : 29
# Train Loss : 74.4079  Train R2 : 0.1264
# Test Loss : 64.6456  Test R2 : 0.2001
# Epoch : 30
# Train Loss : 74.6587  Train R2 : 0.1289
# Test Loss : 63.8491  Test R2 : 0.2100
# Epoch : 31
# Train Loss : 73.7997  Train R2 : 0.1358
# Test Loss : 63.0757  Test R2 : 0.2196
# Epoch : 32
# Train Loss : 71.9211  Train R2 : 0.1481
# Test Loss : 62.5979  Test R2 : 0.2255
# Epoch : 33
# Train Loss : 72.6632  Train R2 : 0.1500
# Test Loss : 62.2982  Test R2 : 0.2292
# Epoch : 34
# Train Loss : 72.2251  Train R2 : 0.1527
# Test Loss : 61.0744  Test R2 : 0.2443
# Epoch : 35
# Train Loss : 71.5367  Train R2 : 0.1637
# Test Loss : 60.3268  Test R2 : 0.2536
# Epoch : 36
# Train Loss : 70.3662  Train R2 : 0.1741
# Test Loss : 60.2297  Test R2 : 0.2548
# Epoch : 37
# Train Loss : 70.3300  Train R2 : 0.1708
# Test Loss : 59.7475  Test R2 : 0.2608
# Epoch : 38
# Train Loss : 70.0467  Train R2 : 0.1767
# Test Loss : 59.1865  Test R2 : 0.2677
# Epoch : 39
# Train Loss : 69.4294  Train R2 : 0.1881
# Test Loss : 58.4630  Test R2 : 0.2766
# Epoch : 40
# Train Loss : 69.3818  Train R2 : 0.1896
# Test Loss : 58.0115  Test R2 : 0.2822
# Epoch : 41
# Train Loss : 67.3481  Train R2 : 0.1995
# Test Loss : 57.4921  Test R2 : 0.2887
# Epoch : 42
# Train Loss : 68.3410  Train R2 : 0.2035
# Test Loss : 57.0825  Test R2 : 0.2937
# Epoch : 43
# Train Loss : 67.7198  Train R2 : 0.2074
# Test Loss : 56.7935  Test R2 : 0.2973
# Epoch : 44
# Train Loss : 67.3003  Train R2 : 0.2156
# Test Loss : 56.3805  Test R2 : 0.3024
# Epoch : 45
# Train Loss : 65.7020  Train R2 : 0.2165
# Test Loss : 55.8890  Test R2 : 0.3085
# Epoch : 46
# Train Loss : 66.8797  Train R2 : 0.2191
# Test Loss : 55.5044  Test R2 : 0.3133
# Epoch : 47
# Train Loss : 66.6156  Train R2 : 0.2233
# Test Loss : 55.1731  Test R2 : 0.3174
# Epoch : 48
# Train Loss : 65.8935  Train R2 : 0.2273
# Test Loss : 54.5644  Test R2 : 0.3249
# Epoch : 49
# Train Loss : 65.6506  Train R2 : 0.2348
# Test Loss : 54.5633  Test R2 : 0.3249
# Epoch : 50
# Train Loss : 61.1186  Train R2 : 0.2533
# Test Loss : 54.7012  Test R2 : 0.3232
# Epoch : 51
# Train Loss : 65.4113  Train R2 : 0.2352
# Test Loss : 53.8623  Test R2 : 0.3336
# Epoch : 52
# Train Loss : 64.1753  Train R2 : 0.2426
# Test Loss : 53.1495  Test R2 : 0.3424
# Epoch : 53
# Train Loss : 64.6186  Train R2 : 0.2438
# Test Loss : 52.9179  Test R2 : 0.3453
# Epoch : 54
# Train Loss : 64.3977  Train R2 : 0.2509
# Test Loss : 53.2263  Test R2 : 0.3414
# Epoch : 55
# Train Loss : 64.6063  Train R2 : 0.2476
# Test Loss : 52.3206  Test R2 : 0.3526
# Epoch : 56
# Train Loss : 63.7215  Train R2 : 0.2583
# Test Loss : 52.4605  Test R2 : 0.3509
# Epoch : 57
# Train Loss : 63.3153  Train R2 : 0.2623
# Test Loss : 52.0432  Test R2 : 0.3561
# Epoch : 58
# Train Loss : 63.2824  Train R2 : 0.2564
# Test Loss : 51.4679  Test R2 : 0.3632
# Epoch : 59
# Train Loss : 62.8929  Train R2 : 0.2657
# Test Loss : 51.3621  Test R2 : 0.3645
# Epoch : 60
# Train Loss : 62.7643  Train R2 : 0.2676
# Test Loss : 51.0843  Test R2 : 0.3679
# Epoch : 61
# Train Loss : 62.5100  Train R2 : 0.2718
# Test Loss : 50.9774  Test R2 : 0.3693
# Epoch : 62
# Train Loss : 62.3382  Train R2 : 0.2723
# Test Loss : 50.5120  Test R2 : 0.3750
# Epoch : 63
# Train Loss : 61.2860  Train R2 : 0.2736
# Test Loss : 50.3444  Test R2 : 0.3771
# Epoch : 64
# Train Loss : 61.8651  Train R2 : 0.2760
# Test Loss : 50.0732  Test R2 : 0.3805
# Epoch : 65
# Train Loss : 60.2770  Train R2 : 0.2789
# Test Loss : 50.3270  Test R2 : 0.3773
# Epoch : 66
# Train Loss : 61.4270  Train R2 : 0.2824
# Test Loss : 50.1042  Test R2 : 0.3801
# Epoch : 67
# Train Loss : 62.1532  Train R2 : 0.2765
# Test Loss : 49.3855  Test R2 : 0.3890
# Epoch : 68
# Train Loss : 61.2172  Train R2 : 0.2847
# Test Loss : 49.2999  Test R2 : 0.3900
# Epoch : 69
# Train Loss : 58.2101  Train R2 : 0.3035
# Test Loss : 49.7923  Test R2 : 0.3839
# Epoch : 70
# Train Loss : 60.3660  Train R2 : 0.2871
# Test Loss : 49.1031  Test R2 : 0.3925
# Epoch : 71
# Train Loss : 60.5561  Train R2 : 0.2951
# Test Loss : 48.5529  Test R2 : 0.3993
# Epoch : 72
# Train Loss : 58.0114  Train R2 : 0.2988
# Test Loss : 48.5900  Test R2 : 0.3988
# Epoch : 73
# Train Loss : 60.1565  Train R2 : 0.2964
# Test Loss : 48.4039  Test R2 : 0.4011
# Epoch : 74
# Train Loss : 58.4620  Train R2 : 0.2986
# Test Loss : 48.6056  Test R2 : 0.3986
# Epoch : 75
# Train Loss : 59.9403  Train R2 : 0.2962
# Test Loss : 47.9576  Test R2 : 0.4066
# Epoch : 76
# Train Loss : 59.2877  Train R2 : 0.3034
# Test Loss : 47.9794  Test R2 : 0.4064
# Epoch : 77
# Train Loss : 59.3454  Train R2 : 0.3051
# Test Loss : 47.7996  Test R2 : 0.4086
# Epoch : 78
# Train Loss : 59.6711  Train R2 : 0.3047
# Test Loss : 47.7012  Test R2 : 0.4098
# Epoch : 79
# Train Loss : 59.0312  Train R2 : 0.3098
# Test Loss : 47.3287  Test R2 : 0.4144
# Epoch : 80
# Train Loss : 58.8559  Train R2 : 0.3093
# Test Loss : 47.1441  Test R2 : 0.4167
# Epoch : 81
# Train Loss : 58.9073  Train R2 : 0.3152
# Test Loss : 47.0769  Test R2 : 0.4175
# Epoch : 82
# Train Loss : 58.7732  Train R2 : 0.3151
# Test Loss : 46.8071  Test R2 : 0.4209
# Epoch : 83
# Train Loss : 58.3158  Train R2 : 0.3149
# Test Loss : 46.8908  Test R2 : 0.4198
# Epoch : 84
# Train Loss : 58.5367  Train R2 : 0.3176
# Test Loss : 46.6657  Test R2 : 0.4226
# Epoch : 85
# Train Loss : 55.9779  Train R2 : 0.3303
# Test Loss : 46.4883  Test R2 : 0.4248
# Epoch : 86
# Train Loss : 57.9653  Train R2 : 0.3244
# Test Loss : 46.5322  Test R2 : 0.4243
# Epoch : 87
# Train Loss : 57.7072  Train R2 : 0.3274
# Test Loss : 46.3280  Test R2 : 0.4268
# Epoch : 88
# Train Loss : 57.4982  Train R2 : 0.3189
# Test Loss : 46.2004  Test R2 : 0.4284
# Epoch : 89
# Train Loss : 57.5802  Train R2 : 0.3268
# Test Loss : 45.8726  Test R2 : 0.4324
# Epoch : 90
# Train Loss : 57.9787  Train R2 : 0.3245
# Test Loss : 46.1729  Test R2 : 0.4287
# Epoch : 91
# Train Loss : 57.4150  Train R2 : 0.3257
# Test Loss : 45.7247  Test R2 : 0.4343
# Epoch : 92
# Train Loss : 56.8999  Train R2 : 0.3365
# Test Loss : 45.5415  Test R2 : 0.4365
# Epoch : 93
# Train Loss : 56.9459  Train R2 : 0.3369
# Test Loss : 45.6048  Test R2 : 0.4357
# Epoch : 94
# Train Loss : 54.7786  Train R2 : 0.3467
# Test Loss : 45.4237  Test R2 : 0.4380
# Epoch : 95
# Train Loss : 55.5412  Train R2 : 0.3354
# Test Loss : 45.3542  Test R2 : 0.4388
# Epoch : 96
# Train Loss : 56.7387  Train R2 : 0.3392
# Test Loss : 45.3257  Test R2 : 0.4392
# Epoch : 97
# Train Loss : 55.4701  Train R2 : 0.3402
# Test Loss : 45.3203  Test R2 : 0.4393
# Epoch : 98
# Train Loss : 56.6685  Train R2 : 0.3359
# Test Loss : 45.0007  Test R2 : 0.4432
# Epoch : 99
# Train Loss : 57.0351  Train R2 : 0.3306
# Test Loss : 44.8279  Test R2 : 0.4453
# Epoch : 100
# Train Loss : 53.2184  Train R2 : 0.3411
# Test Loss : 45.4023  Test R2 : 0.4382
# Epoch : 101
# Train Loss : 56.4940  Train R2 : 0.3411
# Test Loss : 44.9443  Test R2 : 0.4439
# Epoch : 102
# Train Loss : 56.3740  Train R2 : 0.3421
# Test Loss : 44.4792  Test R2 : 0.4497
# Epoch : 103
# Train Loss : 55.8950  Train R2 : 0.3451
# Test Loss : 44.6138  Test R2 : 0.4480
# Epoch : 104
# Train Loss : 55.7637  Train R2 : 0.3502
# Test Loss : 44.4551  Test R2 : 0.4500
# Epoch : 105
# Train Loss : 55.6142  Train R2 : 0.3488
# Test Loss : 44.2626  Test R2 : 0.4523
# Epoch : 106
# Train Loss : 55.7937  Train R2 : 0.3478
# Test Loss : 44.4542  Test R2 : 0.4500
# Epoch : 107
# Train Loss : 55.3488  Train R2 : 0.3509
# Test Loss : 44.1662  Test R2 : 0.4535
# Epoch : 108
# Train Loss : 55.3739  Train R2 : 0.3549
# Test Loss : 43.8809  Test R2 : 0.4571
# Epoch : 109
# Train Loss : 54.2545  Train R2 : 0.3529
# Test Loss : 43.8878  Test R2 : 0.4570
# Epoch : 110
# Train Loss : 55.1384  Train R2 : 0.3542
# Test Loss : 44.1155  Test R2 : 0.4542
# Epoch : 111
# Train Loss : 54.9590  Train R2 : 0.3568
# Test Loss : 43.8498  Test R2 : 0.4575
# Epoch : 112
# Train Loss : 53.1666  Train R2 : 0.3604
# Test Loss : 43.7081  Test R2 : 0.4592
# Epoch : 113
# Train Loss : 54.7163  Train R2 : 0.3617
# Test Loss : 43.5068  Test R2 : 0.4617
# Epoch : 114
# Train Loss : 54.7591  Train R2 : 0.3594
# Test Loss : 43.3253  Test R2 : 0.4639
# Epoch : 115
# Train Loss : 54.2480  Train R2 : 0.3631
# Test Loss : 44.1775  Test R2 : 0.4534
# Epoch : 116
# Train Loss : 53.3680  Train R2 : 0.3640
# Test Loss : 43.2890  Test R2 : 0.4644
# Epoch : 117
# Train Loss : 53.9536  Train R2 : 0.3603
# Test Loss : 43.1119  Test R2 : 0.4666
# Epoch : 118
# Train Loss : 54.6031  Train R2 : 0.3646
# Test Loss : 43.0431  Test R2 : 0.4674
# Epoch : 119
# Train Loss : 54.4999  Train R2 : 0.3583
# Test Loss : 43.6312  Test R2 : 0.4602
# Epoch : 120
# Train Loss : 54.3182  Train R2 : 0.3650
# Test Loss : 42.9651  Test R2 : 0.4684
# Epoch : 121
# Train Loss : 53.6246  Train R2 : 0.3692
# Test Loss : 42.7499  Test R2 : 0.4711
# Epoch : 122
# Train Loss : 53.6996  Train R2 : 0.3725
# Test Loss : 43.0273  Test R2 : 0.4676
# Epoch : 123
# Train Loss : 53.9788  Train R2 : 0.3647
# Test Loss : 42.7999  Test R2 : 0.4704
# Epoch : 124
# Train Loss : 53.8280  Train R2 : 0.3703
# Test Loss : 42.5989  Test R2 : 0.4729
# Epoch : 125
# Train Loss : 53.7037  Train R2 : 0.3709
# Test Loss : 42.9216  Test R2 : 0.4689
# Epoch : 126
# Train Loss : 53.3973  Train R2 : 0.3731
# Test Loss : 42.4516  Test R2 : 0.4748
# Epoch : 127
# Train Loss : 53.1035  Train R2 : 0.3746
# Test Loss : 42.3007  Test R2 : 0.4766
# Epoch : 128
# Train Loss : 53.4348  Train R2 : 0.3777
# Test Loss : 42.3886  Test R2 : 0.4755
# Epoch : 129
# Train Loss : 53.4553  Train R2 : 0.3767
# Test Loss : 42.1449  Test R2 : 0.4785
# Epoch : 130
# Train Loss : 53.3322  Train R2 : 0.3761
# Test Loss : 42.5785  Test R2 : 0.4732
# Epoch : 131
# Train Loss : 53.0930  Train R2 : 0.3792
# Test Loss : 42.0233  Test R2 : 0.4801
# Epoch : 132
# Train Loss : 52.7582  Train R2 : 0.3835
# Test Loss : 41.9316  Test R2 : 0.4812
# Epoch : 133
# Train Loss : 52.8450  Train R2 : 0.3776
# Test Loss : 42.0567  Test R2 : 0.4796
# Epoch : 134
# Train Loss : 52.9887  Train R2 : 0.3839
# Test Loss : 41.9250  Test R2 : 0.4813
# Epoch : 135
# Train Loss : 50.6974  Train R2 : 0.3871
# Test Loss : 41.8347  Test R2 : 0.4824
# Epoch : 136
# Train Loss : 52.5394  Train R2 : 0.3863
# Test Loss : 41.7218  Test R2 : 0.4838
# Epoch : 137
# Train Loss : 52.0973  Train R2 : 0.3816
# Test Loss : 41.9895  Test R2 : 0.4805
# Epoch : 138
# Train Loss : 52.5570  Train R2 : 0.3830
# Test Loss : 41.5814  Test R2 : 0.4855
# Epoch : 139
# Train Loss : 52.2156  Train R2 : 0.3904
# Test Loss : 41.5446  Test R2 : 0.4860
# Epoch : 140
# Train Loss : 52.0523  Train R2 : 0.3913
# Test Loss : 41.5163  Test R2 : 0.4863
# Epoch : 141
# Train Loss : 52.0421  Train R2 : 0.3942
# Test Loss : 41.2057  Test R2 : 0.4902
# Epoch : 142
# Train Loss : 51.9878  Train R2 : 0.3946
# Test Loss : 41.3493  Test R2 : 0.4884
# Epoch : 143
# Train Loss : 51.0857  Train R2 : 0.3877
# Test Loss : 42.0888  Test R2 : 0.4792
# Epoch : 144
# Train Loss : 51.5752  Train R2 : 0.3991
# Test Loss : 41.0271  Test R2 : 0.4924
# Epoch : 145
# Train Loss : 51.6263  Train R2 : 0.3964
# Test Loss : 41.0533  Test R2 : 0.4921
# Epoch : 146
# Train Loss : 51.3199  Train R2 : 0.3992
# Test Loss : 40.9165  Test R2 : 0.4937
# Epoch : 147
# Train Loss : 51.4544  Train R2 : 0.3992
# Test Loss : 40.8008  Test R2 : 0.4952
# Epoch : 148
# Train Loss : 51.4103  Train R2 : 0.3989
# Test Loss : 41.3760  Test R2 : 0.4881
# Epoch : 149
# Train Loss : 51.4206  Train R2 : 0.4003
# Test Loss : 40.7485  Test R2 : 0.4958
# Epoch : 150
# Train Loss : 51.2397  Train R2 : 0.4023
# Test Loss : 40.9574  Test R2 : 0.4932
# Epoch : 151
# Train Loss : 51.0040  Train R2 : 0.4056
# Test Loss : 40.6541  Test R2 : 0.4970
# Epoch : 152
# Train Loss : 50.7871  Train R2 : 0.4049
# Test Loss : 40.4882  Test R2 : 0.4990
# Epoch : 153
# Train Loss : 51.0467  Train R2 : 0.4065
# Test Loss : 40.6079  Test R2 : 0.4976
# Epoch : 154
# Train Loss : 49.0434  Train R2 : 0.4104
# Test Loss : 40.5743  Test R2 : 0.4980
# Epoch : 155
# Train Loss : 50.7457  Train R2 : 0.4064
# Test Loss : 40.3441  Test R2 : 0.5008
# Epoch : 156
# Train Loss : 47.0980  Train R2 : 0.4252
# Test Loss : 40.4031  Test R2 : 0.5001
# Epoch : 157
# Train Loss : 50.6066  Train R2 : 0.4117
# Test Loss : 40.6358  Test R2 : 0.4972
# Epoch : 158
# Train Loss : 49.9482  Train R2 : 0.4066
# Test Loss : 40.0614  Test R2 : 0.5043
# Epoch : 159
# Train Loss : 50.1711  Train R2 : 0.4120
# Test Loss : 40.0225  Test R2 : 0.5048
# Epoch : 160
# Train Loss : 50.0115  Train R2 : 0.4134
# Test Loss : 40.1131  Test R2 : 0.5037
# Epoch : 161
# Train Loss : 50.4843  Train R2 : 0.4088
# Test Loss : 40.3505  Test R2 : 0.5007
# Epoch : 162
# Train Loss : 50.3902  Train R2 : 0.4133
# Test Loss : 39.8157  Test R2 : 0.5074
# Epoch : 163
# Train Loss : 50.0416  Train R2 : 0.4153
# Test Loss : 39.9641  Test R2 : 0.5055
# Epoch : 164
# Train Loss : 48.6023  Train R2 : 0.4193
# Test Loss : 39.9043  Test R2 : 0.5063
# Epoch : 165
# Train Loss : 49.7954  Train R2 : 0.4166
# Test Loss : 39.9956  Test R2 : 0.5051
# Epoch : 166
# Train Loss : 49.7276  Train R2 : 0.4163
# Test Loss : 39.6862  Test R2 : 0.5090
# Epoch : 167
# Train Loss : 49.5220  Train R2 : 0.4119
# Test Loss : 39.5004  Test R2 : 0.5113
# Epoch : 168
# Train Loss : 49.4224  Train R2 : 0.4211
# Test Loss : 39.8235  Test R2 : 0.5073
# Epoch : 169
# Train Loss : 49.5431  Train R2 : 0.4215
# Test Loss : 39.4576  Test R2 : 0.5118
# Epoch : 170
# Train Loss : 47.5114  Train R2 : 0.4339
# Test Loss : 39.5265  Test R2 : 0.5109
# Epoch : 171
# Train Loss : 49.9807  Train R2 : 0.4156
# Test Loss : 39.7868  Test R2 : 0.5077
# Epoch : 172
# Train Loss : 48.5880  Train R2 : 0.4254
# Test Loss : 39.1969  Test R2 : 0.5150
# Epoch : 173
# Train Loss : 49.1318  Train R2 : 0.4267
# Test Loss : 39.1836  Test R2 : 0.5152
# Epoch : 174
# Train Loss : 49.0047  Train R2 : 0.4274
# Test Loss : 39.4064  Test R2 : 0.5124
# Epoch : 175
# Train Loss : 48.8494  Train R2 : 0.4305
# Test Loss : 39.3593  Test R2 : 0.5130
# Epoch : 176
# Train Loss : 49.0611  Train R2 : 0.4291
# Test Loss : 38.8942  Test R2 : 0.5188
# Epoch : 177
# Train Loss : 48.9142  Train R2 : 0.4293
# Test Loss : 39.1424  Test R2 : 0.5157
# Epoch : 178
# Train Loss : 47.5663  Train R2 : 0.4282
# Test Loss : 39.1064  Test R2 : 0.5161
# Epoch : 179
# Train Loss : 48.7311  Train R2 : 0.4335
# Test Loss : 38.8397  Test R2 : 0.5194
# Epoch : 180
# Train Loss : 48.1593  Train R2 : 0.4262
# Test Loss : 39.0623  Test R2 : 0.5167
# Epoch : 181
# Train Loss : 48.4167  Train R2 : 0.4361
# Test Loss : 38.6776  Test R2 : 0.5214
# Epoch : 182
# Train Loss : 48.4240  Train R2 : 0.4333
# Test Loss : 38.8266  Test R2 : 0.5196
# Epoch : 183
# Train Loss : 48.1596  Train R2 : 0.4361
# Test Loss : 38.5586  Test R2 : 0.5229
# Epoch : 184
# Train Loss : 47.8155  Train R2 : 0.4353
# Test Loss : 38.3726  Test R2 : 0.5252
# Epoch : 185
# Train Loss : 48.1503  Train R2 : 0.4361
# Test Loss : 38.4181  Test R2 : 0.5247
# Epoch : 186
# Train Loss : 46.7333  Train R2 : 0.4424
# Test Loss : 38.3808  Test R2 : 0.5251
# Epoch : 187
# Train Loss : 48.5197  Train R2 : 0.4341
# Test Loss : 38.7593  Test R2 : 0.5204
# Epoch : 188
# Train Loss : 47.9698  Train R2 : 0.4403
# Test Loss : 38.2182  Test R2 : 0.5271
# Epoch : 189
# Train Loss : 47.9271  Train R2 : 0.4414
# Test Loss : 38.2007  Test R2 : 0.5273
# Epoch : 190
# Train Loss : 47.8144  Train R2 : 0.4417
# Test Loss : 38.2920  Test R2 : 0.5262
# Epoch : 191
# Train Loss : 47.0439  Train R2 : 0.4366
# Test Loss : 38.0495  Test R2 : 0.5292
# Epoch : 192
# Train Loss : 47.6147  Train R2 : 0.4380
# Test Loss : 38.4111  Test R2 : 0.5247
# Epoch : 193
# Train Loss : 44.7027  Train R2 : 0.4603
# Test Loss : 37.8818  Test R2 : 0.5313
# Epoch : 194
# Train Loss : 47.2932  Train R2 : 0.4485
# Test Loss : 37.9687  Test R2 : 0.5302
# Epoch : 195
# Train Loss : 47.6391  Train R2 : 0.4419
# Test Loss : 38.3842  Test R2 : 0.5251
# Epoch : 196
# Train Loss : 47.0238  Train R2 : 0.4515
# Test Loss : 37.6067  Test R2 : 0.5347
# Epoch : 197
# Train Loss : 47.0373  Train R2 : 0.4462
# Test Loss : 37.6110  Test R2 : 0.5346
# Epoch : 198
# Train Loss : 45.5885  Train R2 : 0.4581
# Test Loss : 37.8309  Test R2 : 0.5319
# Epoch : 199
# Train Loss : 46.5195  Train R2 : 0.4452
# Test Loss : 37.5146  Test R2 : 0.5358
# Epoch : 200
# Train Loss : 44.3150  Train R2 : 0.4534
# Test Loss : 38.1139  Test R2 : 0.5284
# Epoch : 201
# Train Loss : 46.5536  Train R2 : 0.4547
# Test Loss : 37.5099  Test R2 : 0.5359
# Epoch : 202
# Train Loss : 47.0246  Train R2 : 0.4506
# Test Loss : 37.4272  Test R2 : 0.5369
# Epoch : 203
# Train Loss : 46.6918  Train R2 : 0.4540
# Test Loss : 37.4898  Test R2 : 0.5361
# Epoch : 204
# Train Loss : 45.1846  Train R2 : 0.4635
# Test Loss : 37.4072  Test R2 : 0.5372
# Epoch : 205
# Train Loss : 43.1491  Train R2 : 0.4725
# Test Loss : 37.4118  Test R2 : 0.5371
# Epoch : 206
# Train Loss : 46.5716  Train R2 : 0.4557
# Test Loss : 37.4276  Test R2 : 0.5369
# Epoch : 207
# Train Loss : 46.3669  Train R2 : 0.4601
# Test Loss : 37.0721  Test R2 : 0.5413
# Epoch : 208
# Train Loss : 45.6361  Train R2 : 0.4554
# Test Loss : 37.2174  Test R2 : 0.5395
# Epoch : 209
# Train Loss : 46.1804  Train R2 : 0.4599
# Test Loss : 36.8590  Test R2 : 0.5439
# Epoch : 210
# Train Loss : 46.0818  Train R2 : 0.4543
# Test Loss : 37.7715  Test R2 : 0.5327
# Epoch : 211
# Train Loss : 46.6133  Train R2 : 0.4519
# Test Loss : 36.8078  Test R2 : 0.5446
# Epoch : 212
# Train Loss : 45.5134  Train R2 : 0.4644
# Test Loss : 37.0259  Test R2 : 0.5419
# Epoch : 213
# Train Loss : 45.9270  Train R2 : 0.4638
# Test Loss : 36.9392  Test R2 : 0.5430
# Epoch : 214
# Train Loss : 45.7499  Train R2 : 0.4658
# Test Loss : 36.8297  Test R2 : 0.5443
# Epoch : 215
# Train Loss : 43.5196  Train R2 : 0.4803
# Test Loss : 36.5293  Test R2 : 0.5480
# Epoch : 216
# Train Loss : 45.6529  Train R2 : 0.4647
# Test Loss : 36.6893  Test R2 : 0.5460
# Epoch : 217
# Train Loss : 45.5743  Train R2 : 0.4634
# Test Loss : 36.7070  Test R2 : 0.5458
# Epoch : 218
# Train Loss : 45.5293  Train R2 : 0.4634
# Test Loss : 36.2766  Test R2 : 0.5512
# Epoch : 219
# Train Loss : 45.4351  Train R2 : 0.4699
# Test Loss : 36.9077  Test R2 : 0.5433
# Epoch : 220
# Train Loss : 43.1248  Train R2 : 0.4857
# Test Loss : 36.2519  Test R2 : 0.5515
# Epoch : 221
# Train Loss : 45.1204  Train R2 : 0.4700
# Test Loss : 36.2068  Test R2 : 0.5520
# Epoch : 222
# Train Loss : 43.4335  Train R2 : 0.4771
# Test Loss : 36.2778  Test R2 : 0.5511
# Epoch : 223
# Train Loss : 44.6681  Train R2 : 0.4769
# Test Loss : 36.1770  Test R2 : 0.5524
# Epoch : 224
# Train Loss : 44.8487  Train R2 : 0.4763
# Test Loss : 35.9657  Test R2 : 0.5550
# Epoch : 225
# Train Loss : 44.7829  Train R2 : 0.4780
# Test Loss : 36.0150  Test R2 : 0.5544
# Epoch : 226
# Train Loss : 44.8410  Train R2 : 0.4771
# Test Loss : 36.0023  Test R2 : 0.5545
# Epoch : 227
# Train Loss : 43.6188  Train R2 : 0.4763
# Test Loss : 36.0013  Test R2 : 0.5546
# Epoch : 228
# Train Loss : 42.3970  Train R2 : 0.4922
# Test Loss : 36.1061  Test R2 : 0.5533
# Epoch : 229
# Train Loss : 44.1999  Train R2 : 0.4776
# Test Loss : 35.6625  Test R2 : 0.5588
# Epoch : 230
# Train Loss : 44.4258  Train R2 : 0.4760
# Test Loss : 35.7760  Test R2 : 0.5573
# Epoch : 231
# Train Loss : 44.2949  Train R2 : 0.4809
# Test Loss : 35.5370  Test R2 : 0.5603
# Epoch : 232
# Train Loss : 44.3264  Train R2 : 0.4829
# Test Loss : 35.5985  Test R2 : 0.5595
# Epoch : 233
# Train Loss : 44.1181  Train R2 : 0.4835
# Test Loss : 35.5351  Test R2 : 0.5603
# Epoch : 234
# Train Loss : 43.7930  Train R2 : 0.4881
# Test Loss : 35.3547  Test R2 : 0.5626
# Epoch : 235
# Train Loss : 44.0865  Train R2 : 0.4860
# Test Loss : 35.3120  Test R2 : 0.5631
# Epoch : 236
# Train Loss : 44.1197  Train R2 : 0.4845
# Test Loss : 35.1844  Test R2 : 0.5647
# Epoch : 237
# Train Loss : 42.9795  Train R2 : 0.4879
# Test Loss : 35.7476  Test R2 : 0.5577
# Epoch : 238
# Train Loss : 43.8905  Train R2 : 0.4888
# Test Loss : 35.0312  Test R2 : 0.5666
# Epoch : 239
# Train Loss : 42.0550  Train R2 : 0.4955
# Test Loss : 35.2282  Test R2 : 0.5641
# Epoch : 240
# Train Loss : 43.4771  Train R2 : 0.4917
# Test Loss : 35.1961  Test R2 : 0.5645
# Epoch : 241
# Train Loss : 43.6247  Train R2 : 0.4853
# Test Loss : 34.9215  Test R2 : 0.5679
# Epoch : 242
# Train Loss : 43.8694  Train R2 : 0.4887
# Test Loss : 34.7384  Test R2 : 0.5702
# Epoch : 243
# Train Loss : 43.5419  Train R2 : 0.4930
# Test Loss : 34.9502  Test R2 : 0.5676
# Epoch : 244
# Train Loss : 43.1083  Train R2 : 0.4934
# Test Loss : 34.8329  Test R2 : 0.5690
# Epoch : 245
# Train Loss : 43.3352  Train R2 : 0.4963
# Test Loss : 34.5475  Test R2 : 0.5725
# Epoch : 246
# Train Loss : 43.5114  Train R2 : 0.4935
# Test Loss : 34.7272  Test R2 : 0.5703
# Epoch : 247
# Train Loss : 43.3185  Train R2 : 0.4936
# Test Loss : 34.4612  Test R2 : 0.5736
# Epoch : 248
# Train Loss : 43.1254  Train R2 : 0.4873
# Test Loss : 34.5402  Test R2 : 0.5726
# Epoch : 249
# Train Loss : 43.5007  Train R2 : 0.4936
# Test Loss : 35.3542  Test R2 : 0.5626
# Epoch : 250
# Train Loss : 43.9374  Train R2 : 0.4872
# Test Loss : 34.2606  Test R2 : 0.5761
# Epoch : 251
# Train Loss : 42.7548  Train R2 : 0.5028
# Test Loss : 34.5969  Test R2 : 0.5719
# Epoch : 252
# Train Loss : 42.5394  Train R2 : 0.4897
# Test Loss : 34.9383  Test R2 : 0.5677
# Epoch : 253
# Train Loss : 44.3683  Train R2 : 0.4802
# Test Loss : 34.1901  Test R2 : 0.5770
# Epoch : 254
# Train Loss : 42.4988  Train R2 : 0.5053
# Test Loss : 34.9875  Test R2 : 0.5671
# Epoch : 255
# Train Loss : 42.9155  Train R2 : 0.4950
# Test Loss : 34.1781  Test R2 : 0.5771
# Epoch : 256
# Train Loss : 42.7768  Train R2 : 0.4999
# Test Loss : 33.8797  Test R2 : 0.5808
# Epoch : 257
# Train Loss : 42.5500  Train R2 : 0.5026
# Test Loss : 34.1429  Test R2 : 0.5776
# Epoch : 258
# Train Loss : 42.1089  Train R2 : 0.5105
# Test Loss : 33.9420  Test R2 : 0.5800
# Epoch : 259
# Train Loss : 42.4817  Train R2 : 0.5010
# Test Loss : 33.7651  Test R2 : 0.5822
# Epoch : 260
# Train Loss : 42.2899  Train R2 : 0.5071
# Test Loss : 33.8648  Test R2 : 0.5810
# Epoch : 261
# Train Loss : 41.6734  Train R2 : 0.5131
# Test Loss : 33.8030  Test R2 : 0.5818
# Epoch : 262
# Train Loss : 42.1113  Train R2 : 0.5065
# Test Loss : 33.6441  Test R2 : 0.5837
# Epoch : 263
# Train Loss : 41.4829  Train R2 : 0.5042
# Test Loss : 33.6421  Test R2 : 0.5838
# Epoch : 264
# Train Loss : 42.0741  Train R2 : 0.5104
# Test Loss : 33.7201  Test R2 : 0.5828
# Epoch : 265
# Train Loss : 41.7595  Train R2 : 0.5132
# Test Loss : 33.4816  Test R2 : 0.5857
# Epoch : 266
# Train Loss : 41.8676  Train R2 : 0.5133
# Test Loss : 33.2825  Test R2 : 0.5882
# Epoch : 267
# Train Loss : 41.8736  Train R2 : 0.5096
# Test Loss : 33.3345  Test R2 : 0.5876
# Epoch : 268
# Train Loss : 41.3741  Train R2 : 0.5147
# Test Loss : 33.3678  Test R2 : 0.5871
# Epoch : 269
# Train Loss : 41.4106  Train R2 : 0.5174
# Test Loss : 33.0847  Test R2 : 0.5906
# Epoch : 270
# Train Loss : 41.2714  Train R2 : 0.5178
# Test Loss : 33.4260  Test R2 : 0.5864
# Epoch : 271
# Train Loss : 40.5198  Train R2 : 0.5148
# Test Loss : 33.0176  Test R2 : 0.5915
# Epoch : 272
# Train Loss : 41.2153  Train R2 : 0.5195
# Test Loss : 33.0752  Test R2 : 0.5908
# Epoch : 273
# Train Loss : 40.9054  Train R2 : 0.5188
# Test Loss : 32.9780  Test R2 : 0.5920
# Epoch : 274
# Train Loss : 41.3605  Train R2 : 0.5170
# Test Loss : 32.9321  Test R2 : 0.5925
# Epoch : 275
# Train Loss : 41.5025  Train R2 : 0.5168
# Test Loss : 33.4332  Test R2 : 0.5863
# Epoch : 276
# Train Loss : 41.0554  Train R2 : 0.5181
# Test Loss : 32.7972  Test R2 : 0.5942
# Epoch : 277
# Train Loss : 41.0030  Train R2 : 0.5217
# Test Loss : 33.0762  Test R2 : 0.5908
# Epoch : 278
# Train Loss : 39.7754  Train R2 : 0.5273
# Test Loss : 33.1547  Test R2 : 0.5898
# Epoch : 279
# Train Loss : 38.5943  Train R2 : 0.5300
# Test Loss : 32.5044  Test R2 : 0.5978
# Epoch : 280
# Train Loss : 39.9441  Train R2 : 0.5275
# Test Loss : 32.7308  Test R2 : 0.5950
# Epoch : 281
# Train Loss : 40.8095  Train R2 : 0.5209
# Test Loss : 32.7565  Test R2 : 0.5947
# Epoch : 282
# Train Loss : 39.6957  Train R2 : 0.5257
# Test Loss : 32.4389  Test R2 : 0.5986
# Epoch : 283
# Train Loss : 40.5203  Train R2 : 0.5250
# Test Loss : 32.7237  Test R2 : 0.5951
# Epoch : 284
# Train Loss : 40.5415  Train R2 : 0.5271
# Test Loss : 32.5641  Test R2 : 0.5971
# Epoch : 285
# Train Loss : 40.8989  Train R2 : 0.5249
# Test Loss : 32.2811  Test R2 : 0.6006
# Epoch : 286
# Train Loss : 40.3667  Train R2 : 0.5301
# Test Loss : 32.5119  Test R2 : 0.5977
# Epoch : 287
# Train Loss : 40.3789  Train R2 : 0.5263
# Test Loss : 32.3152  Test R2 : 0.6002
# Epoch : 288
# Train Loss : 39.9660  Train R2 : 0.5322
# Test Loss : 32.1689  Test R2 : 0.6020
# Epoch : 289
# Train Loss : 40.2251  Train R2 : 0.5286
# Test Loss : 32.1391  Test R2 : 0.6023
# Epoch : 290
# Train Loss : 39.4035  Train R2 : 0.5298
# Test Loss : 32.4860  Test R2 : 0.5981
# Epoch : 291
# Train Loss : 40.0565  Train R2 : 0.5302
# Test Loss : 32.1066  Test R2 : 0.6027
# Epoch : 292
# Train Loss : 39.9793  Train R2 : 0.5289
# Test Loss : 32.0228  Test R2 : 0.6038
# Epoch : 293
# Train Loss : 39.7636  Train R2 : 0.5319
# Test Loss : 32.2677  Test R2 : 0.6008
# Epoch : 294
# Train Loss : 39.3779  Train R2 : 0.5368
# Test Loss : 31.8603  Test R2 : 0.6058
# Epoch : 295
# Train Loss : 38.8848  Train R2 : 0.5366
# Test Loss : 32.3522  Test R2 : 0.5997
# Epoch : 296
# Train Loss : 39.6025  Train R2 : 0.5361
# Test Loss : 31.7890  Test R2 : 0.6067
# Epoch : 297
# Train Loss : 40.2900  Train R2 : 0.5272
# Test Loss : 31.6125  Test R2 : 0.6089
# Epoch : 298
# Train Loss : 39.3462  Train R2 : 0.5410
# Test Loss : 32.4789  Test R2 : 0.5981
# Epoch : 299
# Train Loss : 39.7186  Train R2 : 0.5380
# Test Loss : 31.8264  Test R2 : 0.6062
# Epoch : 300
# Train Loss : 40.8618  Train R2 : 0.5204
# Test Loss : 31.6252  Test R2 : 0.6087
# Epoch : 301
# Train Loss : 37.2898  Train R2 : 0.5507
# Test Loss : 33.1555  Test R2 : 0.5898
# Epoch : 302
# Train Loss : 39.7713  Train R2 : 0.5338
# Test Loss : 31.9949  Test R2 : 0.6041
# Epoch : 303
# Train Loss : 39.4588  Train R2 : 0.5380
# Test Loss : 31.4816  Test R2 : 0.6105
# Epoch : 304
# Train Loss : 39.2892  Train R2 : 0.5436
# Test Loss : 31.4895  Test R2 : 0.6104
# Epoch : 305
# Train Loss : 39.0465  Train R2 : 0.5433
# Test Loss : 32.0679  Test R2 : 0.6032
# Epoch : 306
# Train Loss : 37.9783  Train R2 : 0.5457
# Test Loss : 31.4334  Test R2 : 0.6111
# Epoch : 307
# Train Loss : 39.1032  Train R2 : 0.5429
# Test Loss : 31.4941  Test R2 : 0.6103
# Epoch : 308
# Train Loss : 37.5285  Train R2 : 0.5503
# Test Loss : 31.6796  Test R2 : 0.6080
# Epoch : 309
# Train Loss : 39.0739  Train R2 : 0.5400
# Test Loss : 31.5887  Test R2 : 0.6092
# Epoch : 310
# Train Loss : 38.7854  Train R2 : 0.5488
# Test Loss : 31.4340  Test R2 : 0.6111
# Epoch : 311
# Train Loss : 38.9670  Train R2 : 0.5441
# Test Loss : 31.3169  Test R2 : 0.6125
# Epoch : 312
# Train Loss : 38.7350  Train R2 : 0.5470
# Test Loss : 31.6476  Test R2 : 0.6084
# Epoch : 313
# Train Loss : 38.0146  Train R2 : 0.5479
# Test Loss : 31.1674  Test R2 : 0.6144
# Epoch : 314
# Train Loss : 38.7549  Train R2 : 0.5450
# Test Loss : 31.5293  Test R2 : 0.6099
# Epoch : 315
# Train Loss : 38.5316  Train R2 : 0.5489
# Test Loss : 31.0930  Test R2 : 0.6153
# Epoch : 316
# Train Loss : 38.4466  Train R2 : 0.5514
# Test Loss : 30.9995  Test R2 : 0.6164
# Epoch : 317
# Train Loss : 38.3147  Train R2 : 0.5537
# Test Loss : 31.1114  Test R2 : 0.6151
# Epoch : 318
# Train Loss : 38.6230  Train R2 : 0.5457
# Test Loss : 30.8473  Test R2 : 0.6183
# Epoch : 319
# Train Loss : 38.3284  Train R2 : 0.5510
# Test Loss : 31.0893  Test R2 : 0.6153
# Epoch : 320
# Train Loss : 38.3003  Train R2 : 0.5522
# Test Loss : 31.0944  Test R2 : 0.6153
# Epoch : 321
# Train Loss : 38.4010  Train R2 : 0.5532
# Test Loss : 30.7736  Test R2 : 0.6192
# Epoch : 322
# Train Loss : 38.0573  Train R2 : 0.5501
# Test Loss : 30.9256  Test R2 : 0.6174
# Epoch : 323
# Train Loss : 38.0741  Train R2 : 0.5551
# Test Loss : 30.8109  Test R2 : 0.6188
# Epoch : 324
# Train Loss : 38.1384  Train R2 : 0.5550
# Test Loss : 30.5561  Test R2 : 0.6219
# Epoch : 325
# Train Loss : 37.5611  Train R2 : 0.5496
# Test Loss : 30.9830  Test R2 : 0.6167
# Epoch : 326
# Train Loss : 37.7874  Train R2 : 0.5593
# Test Loss : 30.6672  Test R2 : 0.6206
# Epoch : 327
# Train Loss : 38.1288  Train R2 : 0.5515
# Test Loss : 30.5495  Test R2 : 0.6220
# Epoch : 328
# Train Loss : 37.6209  Train R2 : 0.5552
# Test Loss : 30.5235  Test R2 : 0.6223
# Epoch : 329
# Train Loss : 38.1648  Train R2 : 0.5542
# Test Loss : 30.5025  Test R2 : 0.6226
# Epoch : 330
# Train Loss : 37.6863  Train R2 : 0.5511
# Test Loss : 31.0372  Test R2 : 0.6160
# Epoch : 331
# Train Loss : 37.7079  Train R2 : 0.5601
# Test Loss : 30.2195  Test R2 : 0.6261
# Epoch : 332
# Train Loss : 37.4842  Train R2 : 0.5581
# Test Loss : 30.3071  Test R2 : 0.6250
# Epoch : 333
# Train Loss : 37.5698  Train R2 : 0.5603
# Test Loss : 30.4176  Test R2 : 0.6236
# Epoch : 334
# Train Loss : 37.3898  Train R2 : 0.5655
# Test Loss : 30.4256  Test R2 : 0.6235
# Epoch : 335
# Train Loss : 35.9632  Train R2 : 0.5569
# Test Loss : 30.2840  Test R2 : 0.6253
# Epoch : 336
# Train Loss : 36.6412  Train R2 : 0.5591
# Test Loss : 30.1760  Test R2 : 0.6266
# Epoch : 337
# Train Loss : 37.0305  Train R2 : 0.5679
# Test Loss : 30.2091  Test R2 : 0.6262
# Epoch : 338
# Train Loss : 37.3826  Train R2 : 0.5643
# Test Loss : 30.3248  Test R2 : 0.6248
# Epoch : 339
# Train Loss : 37.2941  Train R2 : 0.5660
# Test Loss : 29.8625  Test R2 : 0.6305
# Epoch : 340
# Train Loss : 37.2560  Train R2 : 0.5660
# Test Loss : 29.9039  Test R2 : 0.6300
# Epoch : 341
# Train Loss : 36.2408  Train R2 : 0.5683
# Test Loss : 30.0870  Test R2 : 0.6277
# Epoch : 342
# Train Loss : 37.3192  Train R2 : 0.5637
# Test Loss : 29.7050  Test R2 : 0.6325
# Epoch : 343
# Train Loss : 37.1522  Train R2 : 0.5665
# Test Loss : 30.1796  Test R2 : 0.6266
# Epoch : 344
# Train Loss : 36.6472  Train R2 : 0.5631
# Test Loss : 30.0184  Test R2 : 0.6286
# Epoch : 345
# Train Loss : 37.0028  Train R2 : 0.5695
# Test Loss : 29.5809  Test R2 : 0.6340
# Epoch : 346
# Train Loss : 37.0021  Train R2 : 0.5633
# Test Loss : 29.7137  Test R2 : 0.6324
# Epoch : 347
# Train Loss : 36.9500  Train R2 : 0.5687
# Test Loss : 29.9358  Test R2 : 0.6296
# Epoch : 348
# Train Loss : 37.1260  Train R2 : 0.5664
# Test Loss : 29.6438  Test R2 : 0.6332
# Epoch : 349
# Train Loss : 37.2326  Train R2 : 0.5615
# Test Loss : 29.3557  Test R2 : 0.6368
# Epoch : 350
# Train Loss : 36.2573  Train R2 : 0.5708
# Test Loss : 30.2313  Test R2 : 0.6260
# Epoch : 351
# Train Loss : 35.6578  Train R2 : 0.5746
# Test Loss : 29.3575  Test R2 : 0.6368
# Epoch : 352
# Train Loss : 36.7767  Train R2 : 0.5715
# Test Loss : 29.2411  Test R2 : 0.6382
# Epoch : 353
# Train Loss : 36.5909  Train R2 : 0.5715
# Test Loss : 29.6716  Test R2 : 0.6329
# Epoch : 354
# Train Loss : 36.0796  Train R2 : 0.5698
# Test Loss : 29.3942  Test R2 : 0.6363
# Epoch : 355
# Train Loss : 36.4921  Train R2 : 0.5701
# Test Loss : 29.3266  Test R2 : 0.6371
# Epoch : 356
# Train Loss : 35.5974  Train R2 : 0.5744
# Test Loss : 29.2576  Test R2 : 0.6380
# Epoch : 357
# Train Loss : 35.8282  Train R2 : 0.5725
# Test Loss : 29.6512  Test R2 : 0.6331
# Epoch : 358
# Train Loss : 35.0909  Train R2 : 0.5813
# Test Loss : 29.0277  Test R2 : 0.6408
# Epoch : 359
# Train Loss : 36.0884  Train R2 : 0.5787
# Test Loss : 29.3652  Test R2 : 0.6367
# Epoch : 360
# Train Loss : 36.8055  Train R2 : 0.5703
# Test Loss : 29.0941  Test R2 : 0.6400
# Epoch : 361
# Train Loss : 36.3014  Train R2 : 0.5777
# Test Loss : 28.9144  Test R2 : 0.6422
# Epoch : 362
# Train Loss : 36.1590  Train R2 : 0.5743
# Test Loss : 29.0087  Test R2 : 0.6411
# Epoch : 363
# Train Loss : 36.0744  Train R2 : 0.5776
# Test Loss : 28.8543  Test R2 : 0.6430
# Epoch : 364
# Train Loss : 35.2147  Train R2 : 0.5800
# Test Loss : 28.9403  Test R2 : 0.6419
# Epoch : 365
# Train Loss : 36.3577  Train R2 : 0.5772
# Test Loss : 28.9913  Test R2 : 0.6413
# Epoch : 366
# Train Loss : 36.3366  Train R2 : 0.5743
# Test Loss : 29.0058  Test R2 : 0.6411
# Epoch : 367
# Train Loss : 36.5219  Train R2 : 0.5752
# Test Loss : 29.0065  Test R2 : 0.6411
# Epoch : 368
# Train Loss : 35.4077  Train R2 : 0.5772
# Test Loss : 28.5791  Test R2 : 0.6464
# Epoch : 369
# Train Loss : 35.8181  Train R2 : 0.5838
# Test Loss : 29.2034  Test R2 : 0.6387
# Epoch : 370
# Train Loss : 34.6883  Train R2 : 0.5784
# Test Loss : 28.7987  Test R2 : 0.6437
# Epoch : 371
# Train Loss : 36.3387  Train R2 : 0.5763
# Test Loss : 28.4876  Test R2 : 0.6475
# Epoch : 372
# Train Loss : 35.6941  Train R2 : 0.5813
# Test Loss : 29.1334  Test R2 : 0.6395
# Epoch : 373
# Train Loss : 36.5047  Train R2 : 0.5719
# Test Loss : 28.5329  Test R2 : 0.6470
# Epoch : 374
# Train Loss : 35.7770  Train R2 : 0.5831
# Test Loss : 28.3092  Test R2 : 0.6497
# Epoch : 375
# Train Loss : 35.7969  Train R2 : 0.5830
# Test Loss : 28.5042  Test R2 : 0.6473
# Epoch : 376
# Train Loss : 35.6840  Train R2 : 0.5822
# Test Loss : 28.4808  Test R2 : 0.6476
# Epoch : 377
# Train Loss : 32.9666  Train R2 : 0.5993
# Test Loss : 28.7168  Test R2 : 0.6447
# Epoch : 378
# Train Loss : 35.7829  Train R2 : 0.5826
# Test Loss : 28.2805  Test R2 : 0.6501
# Epoch : 379
# Train Loss : 35.6590  Train R2 : 0.5852
# Test Loss : 28.1443  Test R2 : 0.6518
# Epoch : 380
# Train Loss : 36.0532  Train R2 : 0.5741
# Test Loss : 28.2313  Test R2 : 0.6507
# Epoch : 381
# Train Loss : 36.3460  Train R2 : 0.5761
# Test Loss : 29.2700  Test R2 : 0.6378
# Epoch : 382
# Train Loss : 35.7093  Train R2 : 0.5711
# Test Loss : 28.3674  Test R2 : 0.6490
# Epoch : 383
# Train Loss : 34.4761  Train R2 : 0.5900
# Test Loss : 28.7209  Test R2 : 0.6446
# Epoch : 384
# Train Loss : 35.9624  Train R2 : 0.5759
# Test Loss : 28.1709  Test R2 : 0.6514
# Epoch : 385
# Train Loss : 35.3748  Train R2 : 0.5869
# Test Loss : 27.9147  Test R2 : 0.6546
# Epoch : 386
# Train Loss : 34.9181  Train R2 : 0.5871
# Test Loss : 28.3173  Test R2 : 0.6496
# Epoch : 387
# Train Loss : 35.3838  Train R2 : 0.5873
# Test Loss : 28.0683  Test R2 : 0.6527
# Epoch : 388
# Train Loss : 35.4219  Train R2 : 0.5817
# Test Loss : 27.7633  Test R2 : 0.6565
# Epoch : 389
# Train Loss : 35.6488  Train R2 : 0.5852
# Test Loss : 27.9849  Test R2 : 0.6537
# Epoch : 390
# Train Loss : 35.1845  Train R2 : 0.5910
# Test Loss : 27.7354  Test R2 : 0.6568
# Epoch : 391
# Train Loss : 35.3700  Train R2 : 0.5882
# Test Loss : 27.9593  Test R2 : 0.6541
# Epoch : 392
# Train Loss : 35.1688  Train R2 : 0.5871
# Test Loss : 28.0497  Test R2 : 0.6529
# Epoch : 393
# Train Loss : 34.3060  Train R2 : 0.5910
# Test Loss : 27.7759  Test R2 : 0.6563
# Epoch : 394
# Train Loss : 35.2083  Train R2 : 0.5886
# Test Loss : 27.5741  Test R2 : 0.6588
# Epoch : 395
# Train Loss : 34.9794  Train R2 : 0.5930
# Test Loss : 27.7198  Test R2 : 0.6570
# Epoch : 396
# Train Loss : 35.2585  Train R2 : 0.5892
# Test Loss : 27.7812  Test R2 : 0.6563
# Epoch : 397
# Train Loss : 35.2918  Train R2 : 0.5896
# Test Loss : 27.4513  Test R2 : 0.6603
# Epoch : 398
# Train Loss : 34.8605  Train R2 : 0.5908
# Test Loss : 27.9048  Test R2 : 0.6547
# Epoch : 399
# Train Loss : 35.0274  Train R2 : 0.5826
# Test Loss : 27.4086  Test R2 : 0.6609
# Epoch : 400
# Train Loss : 35.8072  Train R2 : 0.5797
# Test Loss : 28.5729  Test R2 : 0.6465
# Epoch : 401
# Train Loss : 36.1918  Train R2 : 0.5766
# Test Loss : 27.8207  Test R2 : 0.6558
# Epoch : 402
# Train Loss : 35.0091  Train R2 : 0.5895
# Test Loss : 27.8431  Test R2 : 0.6555
# Epoch : 403
# Train Loss : 35.2039  Train R2 : 0.5884
# Test Loss : 27.4011  Test R2 : 0.6610
# Epoch : 404
# Train Loss : 34.9140  Train R2 : 0.5923
# Test Loss : 27.1909  Test R2 : 0.6636
# Epoch : 405
# Train Loss : 34.6014  Train R2 : 0.5969
# Test Loss : 27.8913  Test R2 : 0.6549
# Epoch : 406
# Train Loss : 34.8079  Train R2 : 0.5942
# Test Loss : 27.2244  Test R2 : 0.6632
# Epoch : 407
# Train Loss : 34.5371  Train R2 : 0.5973
# Test Loss : 27.0613  Test R2 : 0.6652
# Epoch : 408
# Train Loss : 34.6922  Train R2 : 0.5969
# Test Loss : 27.1507  Test R2 : 0.6641
# Epoch : 409
# Train Loss : 33.9594  Train R2 : 0.5991
# Test Loss : 27.2477  Test R2 : 0.6629
# Epoch : 410
# Train Loss : 34.7882  Train R2 : 0.5956
# Test Loss : 27.0367  Test R2 : 0.6655
# Epoch : 411
# Train Loss : 34.1387  Train R2 : 0.5958
# Test Loss : 27.7792  Test R2 : 0.6563
# Epoch : 412
# Train Loss : 34.4173  Train R2 : 0.5958
# Test Loss : 26.9367  Test R2 : 0.6667
# Epoch : 413
# Train Loss : 34.5736  Train R2 : 0.5886
# Test Loss : 26.9859  Test R2 : 0.6661
# Epoch : 414
# Train Loss : 32.9230  Train R2 : 0.6075
# Test Loss : 27.0023  Test R2 : 0.6659
# Epoch : 415
# Train Loss : 34.4930  Train R2 : 0.5961
# Test Loss : 27.2627  Test R2 : 0.6627
# Epoch : 416
# Train Loss : 34.7567  Train R2 : 0.5919
# Test Loss : 26.7459  Test R2 : 0.6691
# Epoch : 417
# Train Loss : 34.1166  Train R2 : 0.5945
# Test Loss : 26.9562  Test R2 : 0.6665
# Epoch : 418
# Train Loss : 34.3154  Train R2 : 0.5988
# Test Loss : 26.9376  Test R2 : 0.6667
# Epoch : 419
# Train Loss : 34.2844  Train R2 : 0.5909
# Test Loss : 26.8078  Test R2 : 0.6683
# Epoch : 420
# Train Loss : 34.4990  Train R2 : 0.5912
# Test Loss : 27.1339  Test R2 : 0.6643
# Epoch : 421
# Train Loss : 34.3549  Train R2 : 0.5987
# Test Loss : 26.5522  Test R2 : 0.6715
# Epoch : 422
# Train Loss : 34.1628  Train R2 : 0.5994
# Test Loss : 27.0639  Test R2 : 0.6651
# Epoch : 423
# Train Loss : 34.3815  Train R2 : 0.5993
# Test Loss : 26.5680  Test R2 : 0.6713
# Epoch : 424
# Train Loss : 34.2435  Train R2 : 0.5998
# Test Loss : 26.8239  Test R2 : 0.6681
# Epoch : 425
# Train Loss : 34.1217  Train R2 : 0.5980
# Test Loss : 26.5793  Test R2 : 0.6711
# Epoch : 426
# Train Loss : 34.1309  Train R2 : 0.6006
# Test Loss : 26.5062  Test R2 : 0.6720
# Epoch : 427
# Train Loss : 34.2397  Train R2 : 0.6014
# Test Loss : 26.3337  Test R2 : 0.6742
# Epoch : 428
# Train Loss : 34.0565  Train R2 : 0.6013
# Test Loss : 26.6391  Test R2 : 0.6704
# Epoch : 429
# Train Loss : 34.0095  Train R2 : 0.6020
# Test Loss : 26.5567  Test R2 : 0.6714
# Epoch : 430
# Train Loss : 32.9703  Train R2 : 0.6090
# Test Loss : 26.4624  Test R2 : 0.6726
# Epoch : 431
# Train Loss : 33.5106  Train R2 : 0.6100
# Test Loss : 26.5682  Test R2 : 0.6713
# Epoch : 432
# Train Loss : 33.4787  Train R2 : 0.6023
# Test Loss : 26.2302  Test R2 : 0.6755
# Epoch : 433
# Train Loss : 33.8191  Train R2 : 0.6052
# Test Loss : 26.3649  Test R2 : 0.6738
# Epoch : 434
# Train Loss : 33.8991  Train R2 : 0.6001
# Test Loss : 26.4280  Test R2 : 0.6730
# Epoch : 435
# Train Loss : 33.8146  Train R2 : 0.6059
# Test Loss : 26.2147  Test R2 : 0.6756
# Epoch : 436
# Train Loss : 31.5742  Train R2 : 0.6205
# Test Loss : 26.4358  Test R2 : 0.6729
# Epoch : 437
# Train Loss : 33.5365  Train R2 : 0.5942
# Test Loss : 26.0147  Test R2 : 0.6781
# Epoch : 438
# Train Loss : 32.6661  Train R2 : 0.6020
# Test Loss : 26.3747  Test R2 : 0.6737
# Epoch : 439
# Train Loss : 32.7589  Train R2 : 0.6072
# Test Loss : 25.9746  Test R2 : 0.6786
# Epoch : 440
# Train Loss : 33.7450  Train R2 : 0.6040
# Test Loss : 26.0422  Test R2 : 0.6778
# Epoch : 441
# Train Loss : 33.5948  Train R2 : 0.6085
# Test Loss : 26.0801  Test R2 : 0.6773
# Epoch : 442
# Train Loss : 32.0646  Train R2 : 0.6160
# Test Loss : 26.2493  Test R2 : 0.6752
# Epoch : 443
# Train Loss : 33.6744  Train R2 : 0.6019
# Test Loss : 25.8321  Test R2 : 0.6804
# Epoch : 444
# Train Loss : 33.3464  Train R2 : 0.6085
# Test Loss : 25.8853  Test R2 : 0.6797
# Epoch : 445
# Train Loss : 33.4482  Train R2 : 0.6107
# Test Loss : 25.8198  Test R2 : 0.6805
# Epoch : 446
# Train Loss : 33.4464  Train R2 : 0.6079
# Test Loss : 25.7847  Test R2 : 0.6810
# Epoch : 447
# Train Loss : 33.6881  Train R2 : 0.6064
# Test Loss : 26.0773  Test R2 : 0.6773
# Epoch : 448
# Train Loss : 33.4312  Train R2 : 0.6103
# Test Loss : 25.6593  Test R2 : 0.6825
# Epoch : 449
# Train Loss : 33.2682  Train R2 : 0.6122
# Test Loss : 25.7959  Test R2 : 0.6808
# Epoch : 450
# Train Loss : 33.1093  Train R2 : 0.6103
# Test Loss : 25.7322  Test R2 : 0.6816
# Epoch : 451
# Train Loss : 33.2215  Train R2 : 0.6125
# Test Loss : 25.6466  Test R2 : 0.6827
# Epoch : 452
# Train Loss : 32.8687  Train R2 : 0.6130
# Test Loss : 25.7246  Test R2 : 0.6817
# Epoch : 453
# Train Loss : 31.5326  Train R2 : 0.6232
# Test Loss : 25.6678  Test R2 : 0.6824
# Epoch : 454
# Train Loss : 32.6944  Train R2 : 0.6079
# Test Loss : 25.4209  Test R2 : 0.6855
# Epoch : 455
# Train Loss : 32.0690  Train R2 : 0.6174
# Test Loss : 25.9175  Test R2 : 0.6793
# Epoch : 456
# Train Loss : 32.7378  Train R2 : 0.6099
# Test Loss : 25.6019  Test R2 : 0.6832
# Epoch : 457
# Train Loss : 33.2525  Train R2 : 0.6108
# Test Loss : 25.4140  Test R2 : 0.6856
# Epoch : 458
# Train Loss : 33.6185  Train R2 : 0.6087
# Test Loss : 25.5062  Test R2 : 0.6844
# Epoch : 459
# Train Loss : 33.1247  Train R2 : 0.6148
# Test Loss : 25.3183  Test R2 : 0.6867
# Epoch : 460
# Train Loss : 33.2081  Train R2 : 0.6128
# Test Loss : 25.4500  Test R2 : 0.6851
# Epoch : 461
# Train Loss : 33.0712  Train R2 : 0.6136
# Test Loss : 25.2891  Test R2 : 0.6871
# Epoch : 462
# Train Loss : 33.1264  Train R2 : 0.6130
# Test Loss : 25.3203  Test R2 : 0.6867
# Epoch : 463
# Train Loss : 32.2229  Train R2 : 0.6256
# Test Loss : 25.3705  Test R2 : 0.6861
# Epoch : 464
# Train Loss : 33.0861  Train R2 : 0.6130
# Test Loss : 25.2570  Test R2 : 0.6875
# Epoch : 465
# Train Loss : 33.0460  Train R2 : 0.6094
# Test Loss : 25.3294  Test R2 : 0.6866
# Epoch : 466
# Train Loss : 33.1703  Train R2 : 0.6139
# Test Loss : 25.8078  Test R2 : 0.6807
# Epoch : 467
# Train Loss : 33.6669  Train R2 : 0.6050
# Test Loss : 25.1063  Test R2 : 0.6894
# Epoch : 468
# Train Loss : 32.6967  Train R2 : 0.6094
# Test Loss : 25.4896  Test R2 : 0.6846
# Epoch : 469
# Train Loss : 32.8990  Train R2 : 0.6162
# Test Loss : 25.2546  Test R2 : 0.6875
# Epoch : 470
# Train Loss : 32.8473  Train R2 : 0.6172
# Test Loss : 25.0428  Test R2 : 0.6901
# Epoch : 471
# Train Loss : 33.1045  Train R2 : 0.6128
# Test Loss : 25.1114  Test R2 : 0.6893
# Epoch : 472
# Train Loss : 32.7905  Train R2 : 0.6174
# Test Loss : 24.8764  Test R2 : 0.6922
# Epoch : 473
# Train Loss : 31.2614  Train R2 : 0.6245
# Test Loss : 25.2569  Test R2 : 0.6875
# Epoch : 474
# Train Loss : 32.2756  Train R2 : 0.6134
# Test Loss : 25.2147  Test R2 : 0.6880
# Epoch : 475
# Train Loss : 31.1111  Train R2 : 0.6227
# Test Loss : 24.9557  Test R2 : 0.6912
# Epoch : 476
# Train Loss : 32.5135  Train R2 : 0.6217
# Test Loss : 25.1228  Test R2 : 0.6892
# Epoch : 477
# Train Loss : 32.2534  Train R2 : 0.6168
# Test Loss : 24.9496  Test R2 : 0.6913
# Epoch : 478
# Train Loss : 32.8178  Train R2 : 0.6177
# Test Loss : 24.8387  Test R2 : 0.6927
# Epoch : 479
# Train Loss : 32.2190  Train R2 : 0.6227
# Test Loss : 24.9515  Test R2 : 0.6913
# Epoch : 480
# Train Loss : 32.3235  Train R2 : 0.6231
# Test Loss : 24.6688  Test R2 : 0.6948
# Epoch : 481
# Train Loss : 32.6801  Train R2 : 0.6184
# Test Loss : 24.9830  Test R2 : 0.6909
# Epoch : 482
# Train Loss : 32.6190  Train R2 : 0.6192
# Test Loss : 24.8002  Test R2 : 0.6932
# Epoch : 483
# Train Loss : 32.4968  Train R2 : 0.6183
# Test Loss : 24.7203  Test R2 : 0.6941
# Epoch : 484
# Train Loss : 32.2948  Train R2 : 0.6236
# Test Loss : 25.1980  Test R2 : 0.6882
# Epoch : 485
# Train Loss : 32.8523  Train R2 : 0.6134
# Test Loss : 24.5222  Test R2 : 0.6966
# Epoch : 486
# Train Loss : 33.0469  Train R2 : 0.6116
# Test Loss : 24.5947  Test R2 : 0.6957
# Epoch : 487
# Train Loss : 32.6354  Train R2 : 0.6195
# Test Loss : 24.9649  Test R2 : 0.6911
# Epoch : 488
# Train Loss : 31.9602  Train R2 : 0.6205
# Test Loss : 24.5122  Test R2 : 0.6967
# Epoch : 489
# Train Loss : 31.5752  Train R2 : 0.6132
# Test Loss : 24.5622  Test R2 : 0.6961
# Epoch : 490
# Train Loss : 32.1759  Train R2 : 0.6219
# Test Loss : 24.7423  Test R2 : 0.6939
# Epoch : 491
# Train Loss : 32.3875  Train R2 : 0.6233
# Test Loss : 24.4449  Test R2 : 0.6975
# Epoch : 492
# Train Loss : 32.4865  Train R2 : 0.6213
# Test Loss : 24.4543  Test R2 : 0.6974
# Epoch : 493
# Train Loss : 32.7445  Train R2 : 0.6184
# Test Loss : 24.4949  Test R2 : 0.6969
# Epoch : 494
# Train Loss : 32.8183  Train R2 : 0.6142
# Test Loss : 24.3399  Test R2 : 0.6988
# Epoch : 495
# Train Loss : 32.3442  Train R2 : 0.6195
# Test Loss : 24.8375  Test R2 : 0.6927
# Epoch : 496
# Train Loss : 31.2873  Train R2 : 0.6233
# Test Loss : 24.4280  Test R2 : 0.6978
# Epoch : 497
# Train Loss : 32.3193  Train R2 : 0.6202
# Test Loss : 24.7324  Test R2 : 0.6940
# Epoch : 498
# Train Loss : 32.3563  Train R2 : 0.6220
# Test Loss : 24.2377  Test R2 : 0.7001
# Epoch : 499
# Train Loss : 32.4455  Train R2 : 0.6164
# Test Loss : 24.5826  Test R2 : 0.6958
# Epoch : 500
# Train Loss : 32.1100  Train R2 : 0.6227
# Test Loss : 24.1080  Test R2 : 0.7017
# Epoch : 501
# Train Loss : 31.3875  Train R2 : 0.6250
# Test Loss : 24.2889  Test R2 : 0.6995
# Epoch : 502
# Train Loss : 32.0521  Train R2 : 0.6250
# Test Loss : 24.3367  Test R2 : 0.6989
# Epoch : 503
# Train Loss : 32.1879  Train R2 : 0.6153
# Test Loss : 24.0911  Test R2 : 0.7019
# Epoch : 504
# Train Loss : 31.8364  Train R2 : 0.6281
# Test Loss : 24.0907  Test R2 : 0.7019
# Epoch : 505
# Train Loss : 31.6187  Train R2 : 0.6232
# Test Loss : 24.1670  Test R2 : 0.7010
# Epoch : 506
# Train Loss : 32.0229  Train R2 : 0.6265
# Test Loss : 23.9885  Test R2 : 0.7032
# Epoch : 507
# Train Loss : 32.1059  Train R2 : 0.6214
# Test Loss : 24.1804  Test R2 : 0.7008
# Epoch : 508
# Train Loss : 31.8854  Train R2 : 0.6272
# Test Loss : 24.3654  Test R2 : 0.6985
# Epoch : 509
# Train Loss : 31.8744  Train R2 : 0.6244
# Test Loss : 23.9489  Test R2 : 0.7037
# Epoch : 510
# Train Loss : 32.0478  Train R2 : 0.6260
# Test Loss : 24.1800  Test R2 : 0.7008
# Epoch : 511
# Train Loss : 30.7923  Train R2 : 0.6315
# Test Loss : 23.9841  Test R2 : 0.7032
# Epoch : 512
# Train Loss : 32.0292  Train R2 : 0.6221
# Test Loss : 23.8416  Test R2 : 0.7050
# Epoch : 513
# Train Loss : 32.0814  Train R2 : 0.6235
# Test Loss : 24.2439  Test R2 : 0.7000
# Epoch : 514
# Train Loss : 31.1625  Train R2 : 0.6276
# Test Loss : 23.7957  Test R2 : 0.7056
# Epoch : 515
# Train Loss : 31.8936  Train R2 : 0.6289
# Test Loss : 24.0168  Test R2 : 0.7028
# Epoch : 516
# Train Loss : 32.0024  Train R2 : 0.6265
# Test Loss : 23.7463  Test R2 : 0.7062
# Epoch : 517
# Train Loss : 32.0133  Train R2 : 0.6216
# Test Loss : 23.7238  Test R2 : 0.7065
# Epoch : 518
# Train Loss : 32.0927  Train R2 : 0.6255
# Test Loss : 23.9897  Test R2 : 0.7032
# Epoch : 519
# Train Loss : 31.8917  Train R2 : 0.6223
# Test Loss : 23.8752  Test R2 : 0.7046
# Epoch : 520
# Train Loss : 31.4092  Train R2 : 0.6331
# Test Loss : 23.9404  Test R2 : 0.7038
# Epoch : 521
# Train Loss : 31.6540  Train R2 : 0.6306
# Test Loss : 23.5486  Test R2 : 0.7086
# Epoch : 522
# Train Loss : 31.0369  Train R2 : 0.6297
# Test Loss : 23.7144  Test R2 : 0.7066
# Epoch : 523
# Train Loss : 31.5858  Train R2 : 0.6286
# Test Loss : 23.5962  Test R2 : 0.7080
# Epoch : 524
# Train Loss : 31.6599  Train R2 : 0.6311
# Test Loss : 23.6544  Test R2 : 0.7073
# Epoch : 525
# Train Loss : 30.2465  Train R2 : 0.6385
# Test Loss : 24.1249  Test R2 : 0.7015
# Epoch : 526
# Train Loss : 31.8200  Train R2 : 0.6295
# Test Loss : 23.4861  Test R2 : 0.7094
# Epoch : 527
# Train Loss : 31.5856  Train R2 : 0.6321
# Test Loss : 23.8180  Test R2 : 0.7053
# Epoch : 528
# Train Loss : 32.0001  Train R2 : 0.6266
# Test Loss : 23.6006  Test R2 : 0.7080
# Epoch : 529
# Train Loss : 31.5505  Train R2 : 0.6327
# Test Loss : 23.3457  Test R2 : 0.7111
# Epoch : 530
# Train Loss : 31.9865  Train R2 : 0.6267
# Test Loss : 23.7172  Test R2 : 0.7065
# Epoch : 531
# Train Loss : 31.4066  Train R2 : 0.6324
# Test Loss : 23.4183  Test R2 : 0.7102
# Epoch : 532
# Train Loss : 31.7928  Train R2 : 0.6272
# Test Loss : 23.8025  Test R2 : 0.7055
# Epoch : 533
# Train Loss : 31.5113  Train R2 : 0.6326
# Test Loss : 23.3201  Test R2 : 0.7115
# Epoch : 534
# Train Loss : 30.7481  Train R2 : 0.6373
# ...
# Test Loss : 14.2068  Test R2 : 0.8242
# Epoch : 9824
# Train Loss : 6.3537  Train R2 : 0.9253
# Test Loss : 14.6313  Test R2 : 0.8190
# Epoch : 9825
# Train Loss : 6.2068  Train R2 : 0.9275
# Test Loss : 14.3032  Test R2 : 0.8230
# Epoch : 9826
# Train Loss : 6.1317  Train R2 : 0.9282
# Test Loss : 14.1408  Test R2 : 0.8250
# Epoch : 9827
# Train Loss : 6.3364  Train R2 : 0.9262
# Test Loss : 14.5120  Test R2 : 0.8204
# Epoch : 9828
# Train Loss : 6.6197  Train R2 : 0.9222
# Test Loss : 14.2725  Test R2 : 0.8234
# Epoch : 9829
# Train Loss : 6.5224  Train R2 : 0.9238
# Test Loss : 14.6859  Test R2 : 0.8183
# Epoch : 9830
# Train Loss : 6.6087  Train R2 : 0.9211
# Test Loss : 14.5988  Test R2 : 0.8194
# Epoch : 9831
# Train Loss : 6.3319  Train R2 : 0.9259
# Test Loss : 14.1007  Test R2 : 0.8255
# Epoch : 9832
# Train Loss : 6.2515  Train R2 : 0.9273
# Test Loss : 14.5113  Test R2 : 0.8205
# Epoch : 9833
# Train Loss : 6.4263  Train R2 : 0.9246
# Test Loss : 14.3157  Test R2 : 0.8229
# Epoch : 9834
# Train Loss : 6.5870  Train R2 : 0.9228
# Test Loss : 14.4387  Test R2 : 0.8214
# Epoch : 9835
# Train Loss : 6.4434  Train R2 : 0.9248
# Test Loss : 14.5896  Test R2 : 0.8195
# Epoch : 9836
# Train Loss : 6.5441  Train R2 : 0.9226
# Test Loss : 14.4561  Test R2 : 0.8211
# Epoch : 9837
# Train Loss : 6.4649  Train R2 : 0.9245
# Test Loss : 14.1965  Test R2 : 0.8243
# Epoch : 9838
# Train Loss : 6.3171  Train R2 : 0.9254
# Test Loss : 14.3251  Test R2 : 0.8228
# Epoch : 9839
# Train Loss : 6.3092  Train R2 : 0.9264
# Test Loss : 14.1247  Test R2 : 0.8252
# Epoch : 9840
# Train Loss : 6.2270  Train R2 : 0.9262
# Test Loss : 14.7066  Test R2 : 0.8180
# Epoch : 9841
# Train Loss : 6.4601  Train R2 : 0.9249
# Test Loss : 14.1881  Test R2 : 0.8245
# Epoch : 9842
# Train Loss : 6.2770  Train R2 : 0.9266
# Test Loss : 14.3963  Test R2 : 0.8219
# Epoch : 9843
# Train Loss : 6.2415  Train R2 : 0.9270
# Test Loss : 14.3451  Test R2 : 0.8225
# Epoch : 9844
# Train Loss : 6.2388  Train R2 : 0.9264
# Test Loss : 14.4098  Test R2 : 0.8217
# Epoch : 9845
# Train Loss : 6.3826  Train R2 : 0.9241
# Test Loss : 14.1630  Test R2 : 0.8248
# Epoch : 9846
# Train Loss : 6.4576  Train R2 : 0.9235
# Test Loss : 14.4161  Test R2 : 0.8216
# Epoch : 9847
# Train Loss : 6.2998  Train R2 : 0.9265
# Test Loss : 14.4431  Test R2 : 0.8213
# Epoch : 9848
# Train Loss : 6.4201  Train R2 : 0.9245
# Test Loss : 14.4971  Test R2 : 0.8206
# Epoch : 9849
# Train Loss : 6.3776  Train R2 : 0.9249
# Test Loss : 14.1905  Test R2 : 0.8244
# Epoch : 9850
# Train Loss : 6.3435  Train R2 : 0.9261
# Test Loss : 14.4312  Test R2 : 0.8214
# Epoch : 9851
# Train Loss : 6.3914  Train R2 : 0.9244
# Test Loss : 14.2727  Test R2 : 0.8234
# Epoch : 9852
# Train Loss : 6.4790  Train R2 : 0.9242
# Test Loss : 14.3331  Test R2 : 0.8227
# Epoch : 9853
# Train Loss : 6.7392  Train R2 : 0.9212
# Test Loss : 14.9612  Test R2 : 0.8149
# Epoch : 9854
# Train Loss : 6.5696  Train R2 : 0.9233
# Test Loss : 14.3034  Test R2 : 0.8230
# Epoch : 9855
# Train Loss : 6.5232  Train R2 : 0.9236
# Test Loss : 14.3610  Test R2 : 0.8223
# Epoch : 9856
# Train Loss : 6.6916  Train R2 : 0.9221
# Test Loss : 14.5802  Test R2 : 0.8196
# Epoch : 9857
# Train Loss : 7.0955  Train R2 : 0.9173
# Test Loss : 15.0055  Test R2 : 0.8143
# Epoch : 9858
# Train Loss : 7.5076  Train R2 : 0.9115
# Test Loss : 15.3138  Test R2 : 0.8105
# Epoch : 9859
# Train Loss : 6.1831  Train R2 : 0.9264
# Test Loss : 13.9761  Test R2 : 0.8271
# Epoch : 9860
# Train Loss : 6.5107  Train R2 : 0.9240
# Test Loss : 14.0987  Test R2 : 0.8256
# Epoch : 9861
# Train Loss : 6.4940  Train R2 : 0.9225
# Test Loss : 14.6293  Test R2 : 0.8190
# Epoch : 9862
# Train Loss : 6.4907  Train R2 : 0.9238
# Test Loss : 13.9920  Test R2 : 0.8269
# Epoch : 9863
# Train Loss : 6.5633  Train R2 : 0.9218
# Test Loss : 14.5236  Test R2 : 0.8203
# Epoch : 9864
# Train Loss : 6.4351  Train R2 : 0.9241
# Test Loss : 14.2056  Test R2 : 0.8242
# Epoch : 9865
# Train Loss : 6.2869  Train R2 : 0.9267
# Test Loss : 14.2009  Test R2 : 0.8243
# Epoch : 9866
# Train Loss : 6.2929  Train R2 : 0.9266
# Test Loss : 14.1800  Test R2 : 0.8246
# Epoch : 9867
# Train Loss : 6.3330  Train R2 : 0.9253
# Test Loss : 14.4184  Test R2 : 0.8216
# Epoch : 9868
# Train Loss : 6.2563  Train R2 : 0.9272
# Test Loss : 14.2153  Test R2 : 0.8241
# Epoch : 9869
# Train Loss : 6.3066  Train R2 : 0.9259
# Test Loss : 14.4701  Test R2 : 0.8210
# Epoch : 9870
# Train Loss : 6.7543  Train R2 : 0.9203
# Test Loss : 14.6338  Test R2 : 0.8189
# Epoch : 9871
# Train Loss : 6.8263  Train R2 : 0.9199
# Test Loss : 14.5762  Test R2 : 0.8197
# Epoch : 9872
# Train Loss : 6.5345  Train R2 : 0.9230
# Test Loss : 14.2458  Test R2 : 0.8237
# Epoch : 9873
# Train Loss : 6.5610  Train R2 : 0.9234
# Test Loss : 14.3144  Test R2 : 0.8229
# Epoch : 9874
# Train Loss : 6.3161  Train R2 : 0.9238
# Test Loss : 14.5339  Test R2 : 0.8202
# Epoch : 9875
# Train Loss : 6.4320  Train R2 : 0.9247
# Test Loss : 14.0830  Test R2 : 0.8258
# Epoch : 9876
# Train Loss : 6.4065  Train R2 : 0.9250
# Test Loss : 14.3221  Test R2 : 0.8228
# Epoch : 9877
# Train Loss : 5.6447  Train R2 : 0.9324
# Test Loss : 14.2762  Test R2 : 0.8234
# Epoch : 9878
# Train Loss : 6.2168  Train R2 : 0.9276
# Test Loss : 14.2980  Test R2 : 0.8231
# Epoch : 9879
# Train Loss : 6.3461  Train R2 : 0.9248
# Test Loss : 14.1216  Test R2 : 0.8253
# Epoch : 9880
# Train Loss : 6.1934  Train R2 : 0.9271
# Test Loss : 14.7034  Test R2 : 0.8181
# Epoch : 9881
# Train Loss : 6.2888  Train R2 : 0.9259
# Test Loss : 14.2789  Test R2 : 0.8233
# Epoch : 9882
# Train Loss : 6.4116  Train R2 : 0.9245
# Test Loss : 14.1422  Test R2 : 0.8250
# Epoch : 9883
# Train Loss : 6.3151  Train R2 : 0.9249
# Test Loss : 14.2792  Test R2 : 0.8233
# Epoch : 9884
# Train Loss : 6.3336  Train R2 : 0.9243
# Test Loss : 14.4209  Test R2 : 0.8216
# Epoch : 9885
# Train Loss : 5.5799  Train R2 : 0.9333
# Test Loss : 14.1653  Test R2 : 0.8247
# Epoch : 9886
# Train Loss : 6.2214  Train R2 : 0.9269
# Test Loss : 14.2492  Test R2 : 0.8237
# Epoch : 9887
# Train Loss : 6.3441  Train R2 : 0.9256
# Test Loss : 14.3466  Test R2 : 0.8225
# Epoch : 9888
# Train Loss : 6.2960  Train R2 : 0.9247
# Test Loss : 14.3684  Test R2 : 0.8222
# Epoch : 9889
# Train Loss : 6.4332  Train R2 : 0.9252
# Test Loss : 14.9722  Test R2 : 0.8148
# Epoch : 9890
# Train Loss : 6.4548  Train R2 : 0.9225
# Test Loss : 14.0082  Test R2 : 0.8267
# Epoch : 9891
# Train Loss : 6.3256  Train R2 : 0.9262
# Test Loss : 14.6679  Test R2 : 0.8185
# Epoch : 9892
# Train Loss : 6.3823  Train R2 : 0.9250
# Test Loss : 14.3942  Test R2 : 0.8219
# Epoch : 9893
# Train Loss : 6.2745  Train R2 : 0.9249
# Test Loss : 14.3651  Test R2 : 0.8223
# Epoch : 9894
# Train Loss : 6.2509  Train R2 : 0.9265
# Test Loss : 14.4924  Test R2 : 0.8207
# Epoch : 9895
# Train Loss : 6.2494  Train R2 : 0.9255
# Test Loss : 14.3340  Test R2 : 0.8226
# Epoch : 9896
# Train Loss : 6.3359  Train R2 : 0.9228
# Test Loss : 14.0958  Test R2 : 0.8256
# Epoch : 9897
# Train Loss : 6.1859  Train R2 : 0.9278
# Test Loss : 14.3800  Test R2 : 0.8221
# Epoch : 9898
# Train Loss : 6.5833  Train R2 : 0.9230
# Test Loss : 14.3155  Test R2 : 0.8229
# Epoch : 9899
# Train Loss : 6.3772  Train R2 : 0.9259
# Test Loss : 14.4188  Test R2 : 0.8216
# Epoch : 9900
# Train Loss : 6.4313  Train R2 : 0.9251
# Test Loss : 14.1512  Test R2 : 0.8249
# Epoch : 9901
# Train Loss : 6.3000  Train R2 : 0.9245
# Test Loss : 14.4108  Test R2 : 0.8217
# Epoch : 9902
# Train Loss : 6.4756  Train R2 : 0.9237
# Test Loss : 14.6458  Test R2 : 0.8188
# Epoch : 9903
# Train Loss : 6.4135  Train R2 : 0.9254
# Test Loss : 14.5126  Test R2 : 0.8204
# Epoch : 9904
# Train Loss : 6.3727  Train R2 : 0.9257
# Test Loss : 14.1164  Test R2 : 0.8253
# Epoch : 9905
# Train Loss : 5.6579  Train R2 : 0.9323
# Test Loss : 14.8201  Test R2 : 0.8166
# Epoch : 9906
# Train Loss : 6.3590  Train R2 : 0.9251
# Test Loss : 14.5614  Test R2 : 0.8198
# Epoch : 9907
# Train Loss : 6.6449  Train R2 : 0.9222
# Test Loss : 14.5887  Test R2 : 0.8195
# Epoch : 9908
# Train Loss : 6.4826  Train R2 : 0.9223
# Test Loss : 14.3660  Test R2 : 0.8223
# Epoch : 9909
# Train Loss : 6.3408  Train R2 : 0.9263
# Test Loss : 14.1003  Test R2 : 0.8255
# Epoch : 9910
# Train Loss : 6.2850  Train R2 : 0.9262
# Test Loss : 14.2094  Test R2 : 0.8242
# Epoch : 9911
# Train Loss : 6.3732  Train R2 : 0.9256
# Test Loss : 14.3865  Test R2 : 0.8220
# Epoch : 9912
# Train Loss : 6.4552  Train R2 : 0.9232
# Test Loss : 14.5361  Test R2 : 0.8201
# Epoch : 9913
# Train Loss : 6.3562  Train R2 : 0.9259
# Test Loss : 14.3157  Test R2 : 0.8229
# Epoch : 9914
# Train Loss : 6.2390  Train R2 : 0.9273
# Test Loss : 14.3363  Test R2 : 0.8226
# Epoch : 9915
# Train Loss : 6.4049  Train R2 : 0.9245
# Test Loss : 14.6227  Test R2 : 0.8191
# Epoch : 9916
# Train Loss : 6.6687  Train R2 : 0.9201
# Test Loss : 15.2992  Test R2 : 0.8107
# Epoch : 9917
# Train Loss : 6.6049  Train R2 : 0.9227
# Test Loss : 14.0788  Test R2 : 0.8258
# Epoch : 9918
# Train Loss : 6.2915  Train R2 : 0.9266
# Test Loss : 14.2507  Test R2 : 0.8237
# Epoch : 9919
# Train Loss : 6.3204  Train R2 : 0.9254
# Test Loss : 14.6379  Test R2 : 0.8189
# Epoch : 9920
# Train Loss : 6.2657  Train R2 : 0.9264
# Test Loss : 14.0922  Test R2 : 0.8256
# Epoch : 9921
# Train Loss : 6.3507  Train R2 : 0.9260
# Test Loss : 14.5980  Test R2 : 0.8194
# Epoch : 9922
# Train Loss : 6.2236  Train R2 : 0.9276
# Test Loss : 14.4265  Test R2 : 0.8215
# Epoch : 9923
# Train Loss : 6.2521  Train R2 : 0.9265
# Test Loss : 14.2368  Test R2 : 0.8238
# Epoch : 9924
# Train Loss : 6.2273  Train R2 : 0.9273
# Test Loss : 14.1370  Test R2 : 0.8251
# Epoch : 9925
# Train Loss : 6.4513  Train R2 : 0.9248
# Test Loss : 14.3506  Test R2 : 0.8224
# Epoch : 9926
# Train Loss : 6.4506  Train R2 : 0.9248
# Test Loss : 14.4532  Test R2 : 0.8212
# Epoch : 9927
# Train Loss : 6.3485  Train R2 : 0.9255
# Test Loss : 14.3330  Test R2 : 0.8227
# Epoch : 9928
# Train Loss : 6.1838  Train R2 : 0.9276
# Test Loss : 14.4962  Test R2 : 0.8206
# Epoch : 9929
# Train Loss : 6.4363  Train R2 : 0.9245
# Test Loss : 14.0472  Test R2 : 0.8262
# Epoch : 9930
# Train Loss : 6.4077  Train R2 : 0.9254
# Test Loss : 14.3354  Test R2 : 0.8226
# Epoch : 9931
# Train Loss : 6.4242  Train R2 : 0.9249
# Test Loss : 14.2688  Test R2 : 0.8235
# Epoch : 9932
# Train Loss : 6.2634  Train R2 : 0.9261
# Test Loss : 14.3173  Test R2 : 0.8229
# Epoch : 9933
# Train Loss : 6.3865  Train R2 : 0.9257
# Test Loss : 14.5979  Test R2 : 0.8194
# Epoch : 9934
# Train Loss : 6.3225  Train R2 : 0.9263
# Test Loss : 14.1584  Test R2 : 0.8248
# Epoch : 9935
# Train Loss : 6.5933  Train R2 : 0.9230
# Test Loss : 14.3907  Test R2 : 0.8219
# Epoch : 9936
# Train Loss : 6.5608  Train R2 : 0.9232
# Test Loss : 14.9517  Test R2 : 0.8150
# Epoch : 9937
# Train Loss : 6.3033  Train R2 : 0.9262
# Test Loss : 14.4709  Test R2 : 0.8210
# Epoch : 9938
# Train Loss : 6.5453  Train R2 : 0.9238
# Test Loss : 14.2266  Test R2 : 0.8240
# Epoch : 9939
# Train Loss : 6.1838  Train R2 : 0.9271
# Test Loss : 14.2642  Test R2 : 0.8235
# Epoch : 9940
# Train Loss : 6.2371  Train R2 : 0.9266
# Test Loss : 14.2504  Test R2 : 0.8237
# Epoch : 9941
# Train Loss : 6.2542  Train R2 : 0.9272
# Test Loss : 14.2413  Test R2 : 0.8238
# Epoch : 9942
# Train Loss : 6.2250  Train R2 : 0.9271
# Test Loss : 14.6222  Test R2 : 0.8191
# Epoch : 9943
# Train Loss : 6.2922  Train R2 : 0.9265
# Test Loss : 14.1358  Test R2 : 0.8251
# Epoch : 9944
# Train Loss : 6.2843  Train R2 : 0.9268
# Test Loss : 14.1942  Test R2 : 0.8244
# Epoch : 9945
# Train Loss : 6.2867  Train R2 : 0.9249
# Test Loss : 14.4764  Test R2 : 0.8209
# Epoch : 9946
# Train Loss : 6.3526  Train R2 : 0.9251
# Test Loss : 14.6786  Test R2 : 0.8184
# Epoch : 9947
# Train Loss : 6.2382  Train R2 : 0.9269
# Test Loss : 14.3779  Test R2 : 0.8221
# Epoch : 9948
# Train Loss : 6.3679  Train R2 : 0.9257
# Test Loss : 14.1806  Test R2 : 0.8245
# Epoch : 9949
# Train Loss : 6.3237  Train R2 : 0.9256
# Test Loss : 14.4656  Test R2 : 0.8210
# Epoch : 9950
# Train Loss : 6.2922  Train R2 : 0.9252
# Test Loss : 14.2037  Test R2 : 0.8243
# Epoch : 9951
# Train Loss : 6.3446  Train R2 : 0.9253
# Test Loss : 14.2473  Test R2 : 0.8237
# Epoch : 9952
# Train Loss : 6.3423  Train R2 : 0.9263
# Test Loss : 14.2001  Test R2 : 0.8243
# Epoch : 9953
# Train Loss : 6.4022  Train R2 : 0.9250
# Test Loss : 14.2780  Test R2 : 0.8233
# Epoch : 9954
# Train Loss : 6.5112  Train R2 : 0.9232
# Test Loss : 14.0093  Test R2 : 0.8267
# Epoch : 9955
# Train Loss : 6.5049  Train R2 : 0.9225
# Test Loss : 14.5629  Test R2 : 0.8198
# Epoch : 9956
# Train Loss : 6.4852  Train R2 : 0.9222
# Test Loss : 14.5706  Test R2 : 0.8197
# Epoch : 9957
# Train Loss : 6.4282  Train R2 : 0.9249
# Test Loss : 14.1223  Test R2 : 0.8253
# Epoch : 9958
# Train Loss : 5.8139  Train R2 : 0.9308
# Test Loss : 14.1981  Test R2 : 0.8243
# Epoch : 9959
# Train Loss : 6.2357  Train R2 : 0.9253
# Test Loss : 14.4012  Test R2 : 0.8218
# Epoch : 9960
# Train Loss : 6.3136  Train R2 : 0.9260
# Test Loss : 14.1157  Test R2 : 0.8253
# Epoch : 9961
# Train Loss : 6.2613  Train R2 : 0.9271
# Test Loss : 14.7864  Test R2 : 0.8170
# Epoch : 9962
# Train Loss : 6.4265  Train R2 : 0.9253
# Test Loss : 14.4807  Test R2 : 0.8208
# Epoch : 9963
# Train Loss : 6.3653  Train R2 : 0.9239
# Test Loss : 14.2145  Test R2 : 0.8241
# Epoch : 9964
# Train Loss : 6.4411  Train R2 : 0.9247
# Test Loss : 14.2436  Test R2 : 0.8238
# Epoch : 9965
# Train Loss : 6.3046  Train R2 : 0.9264
# Test Loss : 14.1094  Test R2 : 0.8254
# Epoch : 9966
# Train Loss : 6.3090  Train R2 : 0.9265
# Test Loss : 14.4382  Test R2 : 0.8214
# Epoch : 9967
# Train Loss : 6.2714  Train R2 : 0.9254
# Test Loss : 14.0703  Test R2 : 0.8259
# Epoch : 9968
# Train Loss : 6.8023  Train R2 : 0.9203
# Test Loss : 15.2179  Test R2 : 0.8117
# Epoch : 9969
# Train Loss : 6.4778  Train R2 : 0.9223
# Test Loss : 14.3701  Test R2 : 0.8222
# Epoch : 9970
# Train Loss : 6.2358  Train R2 : 0.9252
# Test Loss : 14.1607  Test R2 : 0.8248
# Epoch : 9971
# Train Loss : 6.3112  Train R2 : 0.9266
# Test Loss : 14.3481  Test R2 : 0.8225
# Epoch : 9972
# Train Loss : 6.2453  Train R2 : 0.9272
# Test Loss : 14.3442  Test R2 : 0.8225
# Epoch : 9973
# Train Loss : 6.1929  Train R2 : 0.9253
# Test Loss : 14.2378  Test R2 : 0.8238
# Epoch : 9974
# Train Loss : 6.2673  Train R2 : 0.9247
# Test Loss : 14.3052  Test R2 : 0.8230
# Epoch : 9975
# Train Loss : 6.3978  Train R2 : 0.9251
# Test Loss : 14.2167  Test R2 : 0.8241
# Epoch : 9976
# Train Loss : 6.1759  Train R2 : 0.9267
# Test Loss : 14.3756  Test R2 : 0.8221
# Epoch : 9977
# Train Loss : 6.3267  Train R2 : 0.9263
# Test Loss : 14.3095  Test R2 : 0.8230
# Epoch : 9978
# Train Loss : 6.3876  Train R2 : 0.9248
# Test Loss : 14.5109  Test R2 : 0.8205
# Epoch : 9979
# Train Loss : 6.3657  Train R2 : 0.9260
# Test Loss : 14.1725  Test R2 : 0.8246
# Epoch : 9980
# Train Loss : 6.4553  Train R2 : 0.9227
# Test Loss : 14.4388  Test R2 : 0.8214
# Epoch : 9981
# Train Loss : 6.7054  Train R2 : 0.9215
# Test Loss : 15.1968  Test R2 : 0.8120
# Epoch : 9982
# Train Loss : 6.6256  Train R2 : 0.9217
# Test Loss : 14.3401  Test R2 : 0.8226
# Epoch : 9983
# Train Loss : 6.3944  Train R2 : 0.9256
# Test Loss : 14.3256  Test R2 : 0.8228
# Epoch : 9984
# Train Loss : 6.3335  Train R2 : 0.9264
# Test Loss : 14.7976  Test R2 : 0.8169
# Epoch : 9985
# Train Loss : 6.3028  Train R2 : 0.9262
# Test Loss : 14.1191  Test R2 : 0.8253
# Epoch : 9986
# Train Loss : 6.3947  Train R2 : 0.9257
# Test Loss : 14.1616  Test R2 : 0.8248
# Epoch : 9987
# Train Loss : 6.2326  Train R2 : 0.9270
# Test Loss : 14.3404  Test R2 : 0.8226
# Epoch : 9988
# Train Loss : 6.2933  Train R2 : 0.9264
# Test Loss : 14.3078  Test R2 : 0.8230
# Epoch : 9989
# Train Loss : 6.3292  Train R2 : 0.9261
# Test Loss : 14.2486  Test R2 : 0.8237
# Epoch : 9990
# Train Loss : 6.3287  Train R2 : 0.9245
# Test Loss : 15.0846  Test R2 : 0.8134
# Epoch : 9991
# Train Loss : 6.5603  Train R2 : 0.9235
# Test Loss : 14.3328  Test R2 : 0.8227
# Epoch : 9992
# Train Loss : 6.3062  Train R2 : 0.9249
# Test Loss : 14.3895  Test R2 : 0.8220
# Epoch : 9993
# Train Loss : 5.7463  Train R2 : 0.9298
# Test Loss : 14.2809  Test R2 : 0.8233
# Epoch : 9994
# Train Loss : 6.3949  Train R2 : 0.9254
# Test Loss : 14.7833  Test R2 : 0.8171
# Epoch : 9995
# Train Loss : 6.5009  Train R2 : 0.9225
# Test Loss : 14.0957  Test R2 : 0.8256
# Epoch : 9996
# Train Loss : 6.3902  Train R2 : 0.9240
# Test Loss : 14.6099  Test R2 : 0.8192
# Epoch : 9997
# Train Loss : 6.3596  Train R2 : 0.9260
# Test Loss : 14.5489  Test R2 : 0.8200
# Epoch : 9998
# Train Loss : 6.4088  Train R2 : 0.9240
# Test Loss : 14.5990  Test R2 : 0.8194
# Epoch : 9999
# Train Loss : 6.6053  Train R2 : 0.9230
# Test Loss : 14.3378  Test R2 : 0.8226
# Epoch : 10000
# Train Loss : 6.4115  Train R2 : 0.9245
# Test Loss : 14.3558  Test R2 : 0.8224
